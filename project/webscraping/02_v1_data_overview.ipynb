# %% [markdown]
# # Data-Overview of v1 ImmoWelt data

# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Overview

# %%
df = pd.read_csv("./data/v1_property_immowelt_data.csv", sep="|")
df = df.iloc[:, 5:]
df
# Out:
#            price living_space  rooms  \
# 0      189.000 €        58,35      2
# 1      795.150 €       128,25    5,5
# 2      395.000 €        88,79    3,5
# 3      329.000 €          106      4
# 4      420.000 €        73,20      3
# ...          ...          ...    ...
# 18455        383           10  2.474
# 18456         81            4    402
# 18457        160            6    446
# 18458        102         k.A.    110
# 18459         90            4    131
#
#                                                   badges rating_location  \
# 0      Online-Besichtigung möglich;Gewerblicher Anbieter             Gut
# 1      Provisionsfrei;Einzelbesichtigung;Gewerblicher...            Okay
# 2               Einzelbesichtigung;Gewerblicher Anbieter             Gut
# 3                                  Gewerblicher Anbieter            Okay
# 4                                  Gewerblicher Anbieter           Super
# ...

# %%
df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18460 entries, 0 to 18459
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   price                    18460 non-null  object
#  1   living_space             18460 non-null  object
#  2   rooms                    18460 non-null  object
#  3   badges                   18460 non-null  object
#  4   rating_location          18460 non-null  object
#  5   rating_public_transport  18460 non-null  object
#  6   equipments               18460 non-null  object
#  7   features                 18460 non-null  object
#  8   energy_data              14053 non-null  object
#  9   keywords                 18460 non-null  object
# dtypes: object(10)
# memory usage: 1.4+ MB

# %%
df = df[df["rooms"] != "k.A."]
df["rooms"] = df["rooms"].str.replace(",", ".", regex=True)
df["rooms"] = df["rooms"].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18156 entries, 0 to 18459
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   price                    18156 non-null  object
#  1   living_space             18156 non-null  object
#  2   rooms                    18156 non-null  float64
#  3   badges                   18156 non-null  object
#  4   rating_location          18156 non-null  object
#  5   rating_public_transport  18156 non-null  object
#  6   equipments               18156 non-null  object
#  7   features                 18156 non-null  object
#  8   energy_data              13924 non-null  object
#  9   keywords                 18156 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.5+ MB
# /var/folders/2c/nm71sh1102x01ctr3whr9bf40000gn/T/ipykernel_17340/1440636172.py:2: SettingWithCopyWarning:
# ...

# %%
# rooms -> bad!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18156 entries, 0 to 18459
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   price                    18156 non-null  object
#  1   living_space             18156 non-null  object
#  2   rooms                    18156 non-null  float64
#  3   badges                   18156 non-null  object
#  4   rating_location          18156 non-null  object
#  5   rating_public_transport  18156 non-null  object
#  6   equipments               18156 non-null  object
#  7   features                 18156 non-null  object
#  8   energy_data              13924 non-null  object
#  9   keywords                 18156 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.5+ MB

# %%
df.loc[df["rooms"] > 10, "rooms"].count()
# Out:
# 6948

# %%
df.loc[df["rooms"] > 10, "rooms"].min()
# Out:
# 50.0

# %%
invalid_filter = (df["rooms"] % 0.5 != 0) | (df["rooms"] > 10)
df[invalid_filter].shape[0]
# Out:
# 9254

# %%
# invalid rooms -> hardfacts

# %%
df["living_space"].unique()
# Out:
# array(['58,35', '128,25', '88,79', '106', '73,20', '121,14', '124',
#        '54,04', 'k.A.', '142,50', '61', '130', '95,21', '154', '53,48',
#        '83', '98,79', '75', '125', '81,93', '5', '8', '9', '6', '10',
#        '6,5', '7', '5,5', '61,45', '77,10', '71,41', '87,71', '162',
#        '112', '122,56', '99', '47', '50', '62', '51,01', '80,86', '93',
#        '82,80', '90', '55', '77,18', '20', '4', '65', '138', '84,16',
#        '66', '54,03', '58,14', '210', '69,49', '79,60', '140,26', '77,80',
#        '78,44', '65,77', '89,46', '46,99', '68,83', '69,21', '3', '59',
#        '98,49', '84', '100', '122,98', '140', '51', '51,68', '80,25',
#        '54,34', '81,29', '71,48', '64', '64,78', '62,20', '94', '57,21',
#        '58,01', '74', '2', '14', '11', '70', '60', '56', '30', '69', '71',
#        '85,54', '64,59', '118', '67,49', '175', '174,80', '75,18',
#        '70,18', '61,08', '76', '9,5', '156', '57,43', '136', '127', '91',
# ...

# %%
df[df["living_space"] == "k.A."].shape[0]
# Out:
# 1312

# %%
df["badges"].unique()
# Out:
# array(['Online-Besichtigung möglich;Gewerblicher Anbieter',
#        'Provisionsfrei;Einzelbesichtigung;Gewerblicher Anbieter',
#        'Einzelbesichtigung;Gewerblicher Anbieter',
#        'Gewerblicher Anbieter', 'Provisionsfrei;Gewerblicher Anbieter',
#        'Zwangsversteigerung;Gewerblicher Anbieter',
#        'Einzelbesichtigung;Online-Besichtigung möglich;Gewerblicher Anbieter',
#        'Provisionsfrei;Einzelbesichtigung;Online-Besichtigung möglich;Gewerblicher Anbieter',
#        'Privater Anbieter',
#        'Provisionsfrei;Online-Besichtigung möglich;Gewerblicher Anbieter'],
#       dtype=object)

# %%
# badges -> good

# %%
df["rating_location"].unique()
# Out:
# array(['Gut', 'Okay', 'Super', 'Mäßig', 'Wenig'], dtype=object)

# %%
df["rating_public_transport"].unique()
# Out:
# array(['Gut', 'Mäßig', 'Okay', 'Super', 'Wenig'], dtype=object)

# %%
# rating_location & rating_public_transport -> good

# %%
df["equipments"].unique()
# Out:
# array(['Bezug: sofort', 'Wohnungslage: 1. Geschoss',
#        'Wohnungslage: Dachgeschoss;Bezug: Ende 2022/Frühjahr 2023', 'Na',
#        'Wohnungslage: 1. Geschoss;Bezug: sofort',
#        'Wohnungslage: 3. Geschoss;Bezug: Sofort;Derzeitige Nutzung: frei',
#        'Wohnungslage: 1. Geschoss;Bezug: sofort;Derzeitige Nutzung: frei',
#        'Wohnungslage: 2. Geschoss;Bezug: vermietet;Derzeitige Nutzung: vermietet',
#        'Wohnungslage: Dachgeschoss;Bezug: 2021',
#        'Wohnungslage: Erdgeschoss;Bezug: 1. Quartal 2023;Derzeitige Nutzung: frei',
#        'Wohnungslage: Erdgeschoss',
#        'Wohnungslage: 2. Geschoss;Bezug: 01.01.2023',
#        'Bezug: nach Vereinbarung', 'Wohnungslage: 3. Geschoss',
#        'Wohnungslage: Erdgeschoss;Bezug: nach Vereinbarung',
#        'Kategorie: Maisonette;Wohnungslage: 3. Geschoss;Bezug: Nach Absprache',
#        'Kategorie: Doppelhaushälfte;Geschosse: 3 Geschosse;Baujahr: 1960;Bezug: 1961',
# ...

# %%
# equipments -> good

# %%
df["features"].unique()
# Out:
# array(['Baujahr: 1900',
#        'Bad mit Fenster und Dusche, Gäste-WC, Bad/WC getrennt;Balkon;offene Küche, Speisekammer;Böden: Holzdielen, Fliesenboden;Fenster: Kunststofffenster;Zustand: Erstbezug;kontrollierte Be- und Entlüftungsanlage;Weitere Räume: Kelleranteil, Abstellraum;Anschlüsse: Kabelanschluss;Baujahr: 2022;Zustand: Neubau;Personenaufzug;2 Stellplätze: Tiefgarage',
#        'Bad mit Wanne;Balkon, Garten;Einbauküche;Böden: Fliesenboden, Laminat, Parkett;Zustand: gepflegt;Weitere Räume: Kelleranteil;Baujahr: 1969;1 Stellplatz',
#        'Balkon;Böden: Fliesenboden, Parkett;Zustand: gepflegt;Weitere Räume: Abstellraum;Baujahr: 2007',
#        'Balkon;Zustand: gepflegt;Anschlüsse: Kabelanschluss;Baujahr: 1999;Personenaufzug;1 Stellplatz: Tiefgarage',
#        'Balkon;Böden: Parkett;Weitere Räume: Abstellraum;Baujahr: 1971;Personenaufzug;Stellplatz: Tiefgarage',
# ...

# %%
# features -> good

# %%
df["energy_data"].unique()
# Out:
# array(['Energieträger: Öl;Heizungsart: Zentralheizung;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 1900;Wesentliche Energieträger: OEL;Gültigkeit:  06.02.2022 bis 05.02.2032 ;Endenergieverbrauch:  154,20 kWh/(m²·a)  - Warmwasser enthalten ;',
#        'Energieträger: Solar;Haustyp: KfW 55;Heizungsart: Fußbodenheizung, Luft-/Wasser-Wärmepumpe, Zentralheizung;',
#        'Energieträger: Öl;Heizungsart: Zentralheizung;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 1969;Wesentliche Energieträger: Öl;Gültigkeit:  08.05.2018 bis 08.05.2028 ;Effizienzklasse: D;Endenergieverbrauch:  129,00 kWh/(m²·a)  - Warmwasser enthalten ;',
#        'Energieträger: Gas;',
# ...

# %%
# energy_data -> good

# %%
df["keywords"].unique()
# Out:
# array(['Nutzfläche: 5,00 m², Grundstücksfläche: 957,00 m², Anzahl der Schlafzimmer: 1, Anzahl der Badezimmer: 1, Balkon-Terrassen-Fläche: 6,00 m², Anzahl der Wohneinheiten: 10 Weniger anzeigen ',
#        'Versorgung: Städtische Wasserversorgung, Städtische Stromversorgung Weniger anzeigen ',
#        ' Geschäftszeiten Beratungstermine nach Vereinbarung',
#        ' Geschäftszeiten Telefonisch:Montag - Freitag: 09:00 - 18:00Termine nach Vereinbarung',
#        'Serviceleistungen: Hausmeister Weniger anzeigen ',
# ...

# %%
# keywords -> okay, but trim!

# %% [markdown]
# ## Conclusion

# %%
# rooms -> bad
# living_space -> bad
# keywords -> okay, but trim!

# rest good!
# + images scrapen!
