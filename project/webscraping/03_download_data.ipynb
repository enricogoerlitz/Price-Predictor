# %%
import pandas as pd

# %%
GDRIVE_URL = "https://drive.google.com/file/d/16cxEDz38ETPjLlF1uK7QWXnxRRcIJ6r1/view?usp=share_link"
FILE_ID = GDRIVE_URL.split('/')[-2]
DOWNLOAD_URL = f"https://drive.google.com/uc?id={FILE_ID}"
df = pd.read_csv(DOWNLOAD_URL, sep="|")
df
# Out:
#                                           url   category buy_rent  \
# 0      https://www.immowelt.de/expose/28xsk53  wohnungen   kaufen
# 1      https://www.immowelt.de/expose/27egy5v  wohnungen   kaufen
# 2      https://www.immowelt.de/expose/27dc45u  wohnungen   kaufen
# 3      https://www.immowelt.de/expose/28b5m5a  wohnungen   kaufen
# 4      https://www.immowelt.de/expose/2zpe54x  wohnungen   kaufen
# ...                                       ...        ...      ...
# 21170  https://www.immowelt.de/expose/28we65a    haeuser   kaufen
# 21171  https://www.immowelt.de/expose/24stt5n    haeuser   kaufen
# 21172  https://www.immowelt.de/expose/28pan59    haeuser   kaufen
# 21173  https://www.immowelt.de/expose/28uem58    haeuser   kaufen
# 21174  https://www.immowelt.de/expose/27qg55w    haeuser   kaufen
#
#                        state  \
# 0      bl-baden-wuerttemberg
# 1      bl-baden-wuerttemberg
# 2      bl-baden-wuerttemberg
# 3      bl-baden-wuerttemberg
# ...

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (624, 15)

# %%
df.to_csv("./data2/property_data.csv", sep="|", index=None)
