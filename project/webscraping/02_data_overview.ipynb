# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import missingno as msno

from pandas import Series, DataFrame


np.set_printoptions(suppress=True)

sns.set(rc={"figure.figsize": (12, 7), "axes.titlesize": 20, "axes.titleweight": "bold", "axes.labelsize": 15})
sns.set_palette("Set2")
warnings.filterwarnings('ignore')

# %%
def _print(data):
    pd.set_option('display.max_rows', None)
    print(data)

# %%
df = pd.read_csv("./data/property_immowelt_bl-baden-wuerttemberg.csv", sep="|")
df
# Out:
#                                        url   category buy_rent  \
# 0   https://www.immowelt.de/expose/26kv95n  wohnungen   kaufen
# 1   https://www.immowelt.de/expose/27wmr5e  wohnungen   kaufen
# 2   https://www.immowelt.de/expose/2733j5d  wohnungen   kaufen
# 3   https://www.immowelt.de/expose/2757r5c  wohnungen   kaufen
# 4   https://www.immowelt.de/expose/27xae55  wohnungen   kaufen
# ..                                     ...        ...      ...
# 75  https://www.immowelt.de/expose/27rtg5d    haeuser   kaufen
# 76  https://www.immowelt.de/expose/27j7e5d    haeuser   kaufen
# 77  https://www.immowelt.de/expose/27edd5g    haeuser   kaufen
# 78  https://www.immowelt.de/expose/274p65d    haeuser   kaufen
# 79  https://www.immowelt.de/expose/2785p5c    haeuser   kaufen
#
#                     state                                              title  \
# 0   bl-baden-wuerttemberg  ** Stadtwohnung mit kleiner Garten-Terrasse** ...
# 1   bl-baden-wuerttemberg  NEUBAUPROJEKT NUR NOCH 1 WOHNUNG FREI! Stilvol...
# 2   bl-baden-wuerttemberg                  Ruhig gelegene 3,5 Zimmer Wohnung
# 3   bl-baden-wuerttemberg  Wunderschöne 4-Zimmerwohnung über 2 Etagen in ...
# 4   bl-baden-wuerttemberg  Exklusives Wohnen in Seniorenresidenz - Helle ...
# ..                    ...                                                ...
# 75  bl-baden-wuerttemberg  Neubau-Einfamilienhaus für Familien in sonnige...
# 76  bl-baden-wuerttemberg                             Individuell & Exklusiv
# 77  bl-baden-wuerttemberg  Traumhaftes Einfamilienhaus in bester Ortsrand...
# 78  bl-baden-wuerttemberg  In Waldnähe am Tannenberg: Großzügiges Familie...
# 79  bl-baden-wuerttemberg  Familientraum im Eigenheim: Doppelhaushälfte i...
#
#         price living_space  rooms  \
# 0   189.000 €        58,35      2
# 1   795.150 €       128,25    5,5
# 2   395.000 €        88,79    3,5
# 3   329.000 €          106      4
# 4   420.000 €        73,20      3
# ..        ...          ...    ...
# 75        145          5,5    410
# 76        155            7    241
# 77     160,43          5,5    474
# 78        258            9    670
# 79        140          6,5  1.456
#
#                                                badges rating_location  \
# 0   Online-Besichtigung möglich;Gewerblicher Anbieter             Gut
# 1   Provisionsfrei;Einzelbesichtigung;Gewerblicher...            Okay
# 2            Einzelbesichtigung;Gewerblicher Anbieter             Gut
# 3                               Gewerblicher Anbieter            Okay
# 4                               Gewerblicher Anbieter           Super
# ..                                                ...             ...
# 75                              Gewerblicher Anbieter            Okay
# 76                              Gewerblicher Anbieter             Gut
# 77                              Gewerblicher Anbieter           Mäßig
# 78                              Gewerblicher Anbieter           Mäßig
# 79                              Gewerblicher Anbieter            Okay
#
#    rating_public_transport                                         equipments  \
# 0                      Gut                                     Bezug: sofort;
# 1                    Mäßig                         Wohnungslage: 1. Geschoss;
# 2                     Okay  Wohnungslage: Dachgeschoss;Bezug: Ende 2022/Fr...
# 3                    Mäßig                                                 Na
# 4                    Super           Wohnungslage: 1. Geschoss;Bezug: sofort;
# ..                     ...                                                ...
# 75                    Okay          Kategorie: Einfamilienhaus;Baujahr: 2023;
# 76                     Gut         Kategorie: Doppelhaushälfte;Baujahr: 1993;
# 77                   Mäßig  Kategorie: Einfamilienhaus;Baujahr: 2004;Bezug...
# 78                    Okay          Kategorie: Einfamilienhaus;Baujahr: 1972;
# 79                   Mäßig  Kategorie: Doppelhaushälfte;Baujahr: 2019;Bezu...
#
#                                              features  \
# 0                                      Baujahr: 1900;
# 1   Bad mit Fenster und Dusche, Gäste-WC, Bad/WC g...
# 2   Bad mit Wanne;Balkon, Garten;Einbauküche;Böden...
# 3   Balkon;Böden: Fliesenboden, Parkett;Zustand: g...
# 4   Balkon;Zustand: gepflegt;Anschlüsse: Kabelansc...
# ..                                                ...
# 75                                                 Na
# 76  Zustand: gepflegt;voll unterkellert;Terrasse;1...
# 77  Zustand: gepflegt;voll unterkellert;2 Stellplä...
# 78                                                 Na
# 79  voll unterkellert;Terrasse;Gäste-WC;Weitere Rä...
#
#                                           energy_data  \
# 0   Energieträger: Öl;Heizungsart: Zentralheizung;...
# 1   Energieträger: Solar;Haustyp: KfW 55;Heizungsa...
# 2   Energieträger: Öl;Heizungsart: Zentralheizung;...
# 3                                 Energieträger: Gas;
# 4   Energieträger: Gas;Heizungsart: Zentralheizung...
# ..                                                ...
# 75                                                NaN
# 76  Haustyp: Massivhaus;Energieträger: Gas;Heizung...
# 77  Energieausweistyp: Bedarfsausweis;Gebäudetyp: ...
# 78  Energieträger: Holz, Öl;Heizungsart: Zentralhe...
# 79  Heizungsart: Fußbodenheizung, Luft-/Wasser-Wär...
#
#                                              keywords
# 0   Nutzfläche: 5,00 m², Grundstücksfläche: 957,00...
# 1   Versorgung: Städtische Wasserversorgung, Städt...
# 2    Geschäftszeiten Beratungstermine nach Vereinb...
# 3   Versorgung: Städtische Wasserversorgung, Städt...
# 4    Geschäftszeiten Telefonisch:Montag - Freitag:...
# ..                                                ...
# 75   Geschäftszeiten Montag-Freitag 8 - 18 UhrSams...
# 76   Geschäftszeiten Montag bis Freitag von 9:00 b...
# 77   Geschäftszeiten Montag - Donnerstag09:00 - 12...
# 78   Geschäftszeiten Montag-Freitag 8 - 18 UhrSams...
# 79   Geschäftszeiten Mo.-Fr.: 9:00 bis 18:00 Uhr o...
#
# [80 rows x 15 columns]
