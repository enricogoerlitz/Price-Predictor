# %% [markdown]
# # WebScraping on ImmoWelt.de

# %% [markdown]
# ## Imports

# %%
import time

import pandas as pd
import bs4

from datetime import datetime

from bs4 import BeautifulSoup
from bs4 import ResultSet
from bs4.element import Tag as HtmlTag
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager

# %% [markdown]
# ## Script

# %%
BUY_CATEGORIES = ["kaufen"]  # ["kaufen", "mieten"]
PROPERTY_CATEGORIES = ["wohnungen", "haeuser"]
HITS_PER_PAGE = 20
BASE_URL = "https://www.immowelt.de/liste/${state}/${property_category}/${buy_category}?d=true&efs=NEW_BUILDING_PROJECT&sd=DESC&sf=RELEVANCE&sp=${page}"

# %%
states = "Baden-Württemberg, Bayern, Berlin, Brandenburg, Bremen, Hamburg, Hessen, Mecklenburg-Vorpommern, Niedersachsen, Nordrhein-Westfalen, Rheinland-Pfalz, Saarland, Sachsen, Sachsen-Anhalt, Schleswig-Holstein, Thüringen"
states = states.replace("ü", "ue").lower().split(", ")
STATES = [f"bl-{state}" for state in states]
STATES
# Out:
# ['bl-baden-wuerttemberg',
#  'bl-bayern',
#  'bl-berlin',
#  'bl-brandenburg',
#  'bl-bremen',
#  'bl-hamburg',
#  'bl-hessen',
#  'bl-mecklenburg-vorpommern',
#  'bl-niedersachsen',
#  'bl-nordrhein-westfalen',
#  'bl-rheinland-pfalz',
#  'bl-saarland',
#  'bl-sachsen',
#  'bl-sachsen-anhalt',
#  'bl-schleswig-holstein',
#  'bl-thueringen']

# %% [markdown]
# ### General Plan
#
# <ol>
#     <li>Get list of Properties</li>
#     <li>Calculate the total Property pages count</li>
#     <li>Get list of Expose URLs of the page</li>
#     <li>Navigate to the Page and grab the Infos you want</li>
#     <li>Loop</li>
# </ol>

# %%
class ImmoWeltScraper:
    def __init__(
        self,
        base_url: str,
        states: list[str],
        hits_per_page: int,
        property_categories: list[str],
        buy_categories: list[str],
    ) -> None:
        self.TIME_DELAY = 60 * 2.5
        self.driver: webdriver.Chrome = None

        self.base_url = base_url
        self.states = states
        self.hits_per_page = hits_per_page
        self.property_categories = property_categories
        self.buy_categories = buy_categories
    
    def scrape(self) -> pd.DataFrame:
        try:
            self._create_driver()
            df = self._scrape()
            self._log("Script successful finished!", "SUCCESS")
        except Exception as exp:
            self._destroy_driver()
            self._log("Script failed. Try again!", "ERR")
            self._log(str(exp), "ERR_MSG")
            # raise exp
    
    def _scrape(self) -> pd.DataFrame:
        total_loops = len(self.states) * len(self.property_categories) * len(self.buy_categories)
        curr_loop = 0
        total_property_data: list[dict] = []
        for state in self.states:
            state_property_data: list[dict] = []
            for property_category in self.property_categories:
                for buy_category in self.buy_categories:
                    curr_loop += 1
                    self._log(f"Current-Loop: {curr_loop} of {total_loops}")
                    url = self._get_prep_url(state, property_category, buy_category)
                    soup = self._navigate_to(url)
                    if not self._is_page_found(soup):
                        continue
                    
                    page_count = self._calc_total_relevant_page_count(soup)
                    page_count = 35 if page_count > 35 else page_count
                    # page_count = 2 if page_count > 2 else page_count  # just for testing
                    for i in range(0, page_count):
                        page = i + 1
                        self._log(f"State: {state}, Category: {property_category}, Type: {buy_category}, Page: {page} of {page_count}")
                        page_url = self._get_prep_url_page(url, page)
                        soup = self._navigate_to(url)

                        expose_urls = self._get_expose_urls(soup)
                        for expose_url in expose_urls:
                            
                            print(f"URL: {expose_url}")
                            
                            self.driver.get(expose_url)
                            property_data = self._get_property_data(
                                property_category,
                                buy_category,
                                state
                            )

                            print(property_data)

                            state_property_data.append(property_data)
                            total_property_data.append(property_data)
                self._log(f"Category delay of {self.TIME_DELAY}s", "SLEEP")
                time.sleep(self.TIME_DELAY)
            filepath = f"./data/property_immowelt_{state}.csv"
            _ = self._export(state_property_data, filepath)
            self._log(f"State delay of {self.TIME_DELAY}s", "SLEEP")
            time.sleep(self.TIME_DELAY)
        filepath = "./data/property_immowelt_data.csv"
        return self._export(total_property_data, filepath)

    def scrape_obj_test(
        self,
        expose_url: str,
    ) -> dict:
        self._create_driver()
        soup = self._navigate_to(expose_url)
        property_data = self._get_property_data(
            soup,
            "property_category",
            "buy_category",
            "state"
        )
        self._destroy_driver()
        return property_data

    def _create_driver(self) -> None:
        if self.driver:
            self._destroy_driver()
        options = Options()
        options.add_argument("--headless")
        self.driver = webdriver.Chrome(
            service=Service(
                ChromeDriverManager().install()
            ),
            options=options
        )
        self._log("Driver created")
        self._check_permission_requirements()
        self._log("Permissions accepted")

    def _destroy_driver(self) -> None:
        self._log("Destroy driver")
        if not self.driver:
            return
        self.driver.close()
        self.driver = None

    def _check_permission_requirements(self, err_loop: int = 0):
        try:
            self.driver.get("https://www.immowelt.de/immobilienpreise")
            check_element = None
            while not check_element:
                check_element = self.driver.execute_script(
                    """return document.querySelector('#usercentrics-root').shadowRoot.querySelector("button[data-testid='uc-accept-all-button']")"""
                )
                if check_element:
                    check_element.click()
                else:
                    self._log("Permission loop. Wait 2 seconds.")
                    time.sleep(2)
        except Exception as exp:
            err_loop += 1
            if err_loop == 5:
                raise exp
            self._log(f"Permission ERR#{err_loop}-loop", "WARN")
            self._check_permission_requirements(err_loop)

    def _export(self, data: list[dict], filepath: str) -> pd.DataFrame:
        df = pd.DataFrame(data)
        df.replace("|", "_", inplace=True)
        df.to_csv(filepath, sep="|", index=False)
        self._log(f"CSV-Export to: {filepath}")
        return df

    def _navigate_to(self, url: str) -> BeautifulSoup:
        self.driver.get(url)
        return BeautifulSoup(self.driver.page_source)

    def _is_page_found(self, soup: BeautifulSoup) -> bool:
        is_page_found = not soup.find("div", {"class": "NotFound-d39a0"})
        if not is_page_found:
            url = self.driver.current_url
            self._log(f"Page not Found: {url}", "ERROR")
        return is_page_found

    def _log(self, msg: str, tag: str = "INFO") -> None:
        tag = tag.upper()
        ts = datetime.now().strftime("%Y-%m-%d, %H:%M:%S")
        print(f"[{ts}] {tag}:\t{msg}")

    def _get_prep_url(
        self,
        state: str,
        property_category: str,
        buy_category: str,
        page: int = 1
    ) -> str:
        page = str(page)
        return (
            self.base_url
                .replace("${state}", state)
                .replace("${property_category}", property_category)
                .replace("${buy_category}", buy_category)
                .replace("${page}", page)
        )

    def _get_prep_url_page(self, url: str, page: int) -> str:
        url_page_removed = url[:url.find("sp=")]
        return f"{url_page_removed}sp={page}"

    def _calc_total_relevant_page_count(self, soup: BeautifulSoup) -> int:
        hits_emt = soup.find("h1", {"class": "MatchNumber-a225f"})
        if not hits_emt:
            return 0
        content = hits_emt.text
        hits = content[:content.find(" ")].replace(".", "")
        page_count = int(int(hits) / self.hits_per_page)
        return page_count

    def _get_expose_urls(self, soup: BeautifulSoup) -> list[str]:
        expose_urls_emt = soup.find_all("a", {"class": "mainSection-b22fb"})
        expose_urls = [link["href"] for link in expose_urls_emt]
        return expose_urls

    def _expand_read_more_areas(self, err_loop = 0) -> BeautifulSoup:
        try:
            script_expand_all_read_more = """
            let links = document.getElementsByClassName("link--read-more");
            while(links.length > 0) {
                links[0].click(); 
                links = document.getElementsByClassName("link--read-more");
            }
            """
            self.driver.execute_script(script_expand_all_read_more)
            return BeautifulSoup(self.driver.page_source)
        except Exception as exp:
            print("EXEPTION!!")
            if err_loop >= 5:
                raise exp
            err_loop += + 1
            self._log(f"Can't expand read-more. Try: {err_loop} of 5", "WARN")
            self._expand_read_more_areas(err_loop)

    def _get_overview_container(self, soup: BeautifulSoup) -> HtmlTag:
        return soup.find("app-objectmeta", {"id": "aUebersicht"})
    
    def _get_data_title(self, overview_container: HtmlTag) -> str:
        emt = overview_container.find("h1", {"class": "ng-star-inserted"})
        return emt.text if emt else "Na"
    
    def _get_data_hardfacts(self, overview_container: HtmlTag) -> tuple[str, str, str]:
        hardfact_emts = overview_container.find_all("div", {"class": "hardfact ng-star-inserted"})

        def prep_text(emt):
            content: str = emt.text.strip()
            return content[:content.find(" ")]

        hardfact_emt: HtmlTag
        price = "Na"
        living_space = "Na"
        rooms = "Na"
        for hardfact_emt in hardfact_emts:
            hardfact_label = hardfact_emt.find("div", {"class": "hardfact__label"}).text.strip()
            value = prep_text(hardfact_emt)
            if hardfact_label == "Kaufpreis" or hardfact_label == "Mindestpreis":
                price = value
            elif hardfact_label == "Wohnfläche ca.":
                living_space = value
            elif hardfact_label == "Zimmer":
                rooms = value
        
        return price, living_space, rooms
    
    def _get_data_badges(self, overview_container: BeautifulSoup) -> str:
        badge_emts = overview_container.find_all("sd-badge")
        badges = "Na"
        if badge_emts:
            badges = ";".join([legal_info.text for legal_info in badge_emts])
        return badges

    def _get_data_ratings(self, soup: BeautifulSoup) -> tuple[str, str]:
        rating_emts = soup.find_all("div", {"class": "rating-meter__value"})
        location_rating = "Na"
        public_transport_rating = "Na"
        if len(rating_emts) == 2:
            location_rating = rating_emts[0].text
            public_transport_rating = rating_emts[1].text
        return location_rating, public_transport_rating

    def _get_data_equipments(self, soup: BeautifulSoup) -> str:
        equipment_container = soup.find("div", {"class": "equipment card-content ng-star-inserted"})
        if not equipment_container:
            return "Na"

        equipment_cells = equipment_container.find_all("sd-cell-row", {"class": "cell__row"})
        if not equipment_cells:
            return "Na"

        equipments = ""
        equipment_cell: HtmlTag
        for equipment_cell in equipment_cells:
            values = equipment_cell.find_all("p")
            if len(values) >= 2:
                title = values[0].text
                value = values[1].text
                equipments += f"{title}: {value};"

        return equipments[:len(equipments)-1] if equipments else "Na"
    
    def _get_data_features(self, soup: BeautifulSoup) -> str:
        feature_list_emts = soup.find_all("div", {"class": "textlist"})
        if not feature_list_emts:
            return "Na"
        features = ""
        feature_list_emt: HtmlTag
        for feature_list_emt in feature_list_emts:
            feature_emts = feature_list_emt.find_all("li")
            if feature_emts:
                feature_emt: HtmlTag
                for feature_emt in feature_emts:
                    features += f"{feature_emt.text.strip()};"

        return features[:len(features)-1]

    def _get_data_energy_data(self, soup: BeautifulSoup) -> str:
        energy_data = ""

        def get_data(curr_energy_data: str, energy_cells: ResultSet) -> str:
            if not energy_cells:
                return curr_energy_data

            energy_cell: HtmlTag
            for energy_cell in energy_cells:
                content_emts = energy_cell.find_all("p")
                title = content_emts[0].text
                content = content_emts[1].text
                curr_energy_data += f"{title}: {content};"

            return curr_energy_data

        energy_container1 = soup.find("app-energy-equipment")
        if energy_container1:
            energy_cells = energy_container1.find_all("sd-cell-col", {"data-cy": "energy-equipment"})
            energy_data = get_data(energy_data, energy_cells)

        energy_container2 = soup.find("div", {"class": "energy_information ng-star-inserted"})
        if energy_container2:
            energy_cells = energy_container2.find_all("sd-cell-col", {"class": "cell__col"})
            energy_data = get_data(energy_data, energy_cells)

        return energy_data[:len(energy_data)]

    def _get_data_keywords(self, soup: BeautifulSoup) -> str:
        read_more_emts = soup.find_all("sd-read-more")
        keywords = "Na"
        if not read_more_emts:
            return keywords.strip()

        last_emt_idx = len(read_more_emts) - 1
        keywords: str = read_more_emts[last_emt_idx].text
        KEYWORDS_NAME = "Stichworte"
        if not KEYWORDS_NAME in keywords:
            return keywords
        start_idx = keywords.find(KEYWORDS_NAME) + len(KEYWORDS_NAME)
        keywords = keywords[start_idx:]
        return keywords.strip()

    def _get_property_data(
        self,
        category: str,
        buy_rent: str,
        state: str,
    ) -> dict:
        soup = self._expand_read_more_areas()
        overview_container = self._get_overview_container(soup)

        url = self.driver.current_url
        title = self._get_data_title(overview_container)
        price, living_space, rooms = self._get_data_hardfacts(overview_container)
        badges = self._get_data_badges(overview_container)
        rating_location, rating_public_transport = self._get_data_ratings(soup)
        equipments = self._get_data_equipments(soup)
        features = self._get_data_features(soup)
        energy_data = self._get_data_energy_data(soup)
        keywords = self._get_data_keywords(soup)

        return {
            "url": url,
            "category": category,
            "buy_rent": buy_rent,
            "state": state,
            "title": title,
            "price": price,
            "living_space": living_space,
            "rooms": rooms,
            "badges": badges,
            "rating_location": rating_location,
            "rating_public_transport": rating_public_transport,
            "equipments": equipments,
            "features": features,
            "energy_data": energy_data,
            "keywords": keywords
            # image_paths: str,  # later the saved paths!
        }

# %% [markdown]
# ## Run Script

# %%
immo_scraper = ImmoWeltScraper(
    BASE_URL,
    STATES,
    HITS_PER_PAGE,
    PROPERTY_CATEGORIES,
    BUY_CATEGORIES
)
immo_scraper.scrape()
# Out:
# [2022-12-23, 07:50:56] INFO:	Driver created
# [2022-12-23, 07:50:58] INFO:	Permission loop. Wait 2 seconds.
# [2022-12-23, 07:51:00] INFO:	Permissions accepted
# [2022-12-23, 07:51:00] INFO:	Current-Loop: 1 of 32
# [2022-12-23, 07:51:02] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 1 of 30
# URL: https://www.immowelt.de/expose/28xsk53
# {'url': 'https://www.immowelt.de/expose/28xsk53', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'TIENGEN: 3,5-Zimmer-Obergeschosswohnung incl. großem Kellerraum und 2 Tiefgaragenstellplätze.', 'price': '320.000\xa0€', 'living_space': '87', 'rooms': '3,5', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Okay', 'equipments': 'Wohnungslage: 2. Geschoss;Bezug: Nach Vereinbarung!', 'features': 'Balkon;Zustand: gepflegt;Weitere Räume: Kelleranteil;Baujahr: 1995', 'energy_data': 'Heizungsart: Fußbodenheizung;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 1995;Wesentliche Energieträger: GAS;Gültigkeit:  bis 24.11.2018 ;Effizienzklasse: H;Endenergieverbrauch:  170,10 kWh/(m²·a)  - Warmwasser enthalten ;', 'keywords': 'Nutzfläche: 12,00 m², Anzahl der Schlafzimmer: 2, Anzahl der Badezimmer: 1, Anzahl der separaten WCs: 1, Anzahl Balkone: 1, 4 Etagen, Distanz zum Kindergarten: 0.50, Distanz zur Grundschule: 0.50, Distanz zur Realschule: 1.00, Distanz zum Gymnasium: 1.00, Distanz zur Autobahn: 35.00, Distanz vom Zentrum: 0.30 Weniger anzeigen'}
# URL: https://www.immowelt.de/expose/27egy5v
# {'url': 'https://www.immowelt.de/expose/27egy5v', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Investmentchance im Herzen von Konstanz - vergünstigter Preis - Text beachten', 'price': '449.500\xa0€', 'living_space': '79', 'rooms': '2,5', 'badges': 'Provisionsfrei;Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Super', 'equipments': 'Wohnungslage: 2. Geschoss;Bezug: vermietet;Derzeitige Nutzung: vermietet', 'features': 'Bad mit Fenster, Wanne und Dusche;Loggia;Zustand: renovierungsbedürftig / sanierungsbedürftig;Weitere Räume: Kelleranteil;Baujahr: 1998;Personenaufzug', 'energy_data': 'Energieträger: Gas;Heizungsart: Zentralheizung;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 2000;Wesentliche Energieträger: Gas;Gültigkeit:  07.03.2014 bis 06.03.2024 ;Endenergieverbrauch:  95,00 kWh/(m²·a)  - Warmwasser enthalten ;', 'keywords': 'Versorgung: Städtische Wasserversorgung, Städtische StromversorgungServiceleistungen: Hausmeister Weniger anzeigen'}
# URL: https://www.immowelt.de/expose/27dc45u
# {'url': 'https://www.immowelt.de/expose/27dc45u', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Neubau-Erstbezug Eigentumswohnungen', 'price': '465.000\xa0€', 'living_space': '53,99', 'rooms': '2', 'badges': 'Provisionsfrei;Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Gut', 'equipments': 'Kategorie: Terrassenwohnung;Bezug: 2023', 'features': 'Terrasse;Böden: Fliesenboden;Zustand: Erstbezug;Baujahr: 2023;Zustand: Neubau;Personenaufzug;1 Stellplatz: Tiefgarage', 'energy_data': 'Energieträger: Gas;Haustyp: KfW 55;Heizungsart: Luft-/Wasser-Wärmepumpe;', 'keywords': ' Geschäftszeiten Beratungstermine nach Vereinbarung'}
# URL: https://www.immowelt.de/expose/28b5m5a
# {'url': 'https://www.immowelt.de/expose/28b5m5a', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': '**Sofort bezugsfrei** Terrasse + Garten', 'price': '179.000\xa0€', 'living_space': '58,35', 'rooms': '2', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Gut', 'equipments': 'Bezug: sofort', 'features': 'Baujahr: 1900', 'energy_data': 'Energieträger: Öl;Heizungsart: Zentralheizung;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 1900;Wesentliche Energieträger: OEL;Gültigkeit:  06.02.2022 bis 05.02.2032 ;Endenergieverbrauch:  154,20 kWh/(m²·a)  - Warmwasser enthalten ;', 'keywords': 'Nutzfläche: 5,00 m², Grundstücksfläche: 957,00 m², Anzahl der Schlafzimmer: 1, Anzahl der Badezimmer: 1, Balkon-Terrassen-Fläche: 6,00 m², Anzahl der Wohneinheiten: 10 Weniger anzeigen'}
# URL: https://www.immowelt.de/expose/2zpe54x
# {'url': 'https://www.immowelt.de/expose/2zpe54x', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Neue Wohnungen in Durbach-Ebersweier. Hier Wohnung 5 im DG. Baubeginn Januar 2021 und Fertigstellung Ende 2021', 'price': '385.000\xa0€', 'living_space': 'Na', 'rooms': '4', 'badges': 'Provisionsfrei;Gewerblicher Anbieter', 'rating_location': 'Okay', 'rating_public_transport': 'Okay', 'equipments': 'Wohnungslage: Dachgeschoss;Bezug: 2021', 'features': 'Balkon;Fenster: Kunststofffenster;Baujahr: 2021;Stellplätze: Garage, Außen-Stellplatz', 'energy_data': 'Energieträger: Blockheizkraftwerk, Gas;Heizungsart: Fußbodenheizung;Gebäudetyp: Wohngebäude;', 'keywords': 'ObjekteSechs Wohnungen mit vier Zimmern in einem Mehrfamilienhaus. Je nach Baufortschritt besteht noch die Möglichkeit den Grundriss anzupassen..InformationenFür die Erdgeschosswohnungen besteht ein Sondernutzungsrecht am östlichen Grünstreifen der jeweiligen Wohnung.Weitere Informationen gern vorab unter 0781-9705144.KonzeptDie Fassaden der Gesamtanlage bekommen ein Farbkonzept mit gedeckten Farben die sich innerhalb der Anlage wiederholen. Jedes Haus hat aber eine andere Zusammensetzung der Farben. Die Farben können im Original in unserem Büro gezeigt werden.Beheizt wird die Gesamtanlage über ein Blockheizkraftwerk. Dieses erzeugt auch Strom welcher in das Netz wieder eingespeist wird und der Gemeinschaft gut geschrieben wird.BarrierefreiheitBarrierefrei sind die zwei Erdgeschosswohnungen im Mehrfamilienhaus konzipiert.Vorteil ist hierbei dass kein Aufzug für die barrierfreiheit nötig ist - was die Gemeinkosten in Grenzen hält.Gegebenenfalls lässt sich ein Treppenlift z.B. Lifta auch nachträglich einbauen. Weniger anzeigen '}
# URL: https://www.immowelt.de/expose/242tu5x
# {'url': 'https://www.immowelt.de/expose/242tu5x', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Wohnung Nr. 1 "Wohnen unter der Schleicherhütte" Flandernstraße Albstadt-Ebingen', 'price': '316.500\xa0€', 'living_space': '83,67', 'rooms': '3', 'badges': 'Provisionsfrei;Gewerblicher Anbieter', 'rating_location': 'Okay', 'rating_public_transport': 'Okay', 'equipments': 'Wohnungslage: Erdgeschoss', 'features': 'Bad mit Fenster, Wanne und Dusche, Gäste-WC;Terrasse;Ausblick: Fernblick;offene Küche;Böden: Fliesenboden, Parkett;Fenster: Kunststofffenster;Zustand: Erstbezug;Weitere Räume: Kelleranteil, Wasch-Trockenraum;Anschlüsse: Satellitenanschluss;Baujahr: 2022;Zustand: Neubau;Personenaufzug;Stellplätze: Garage, Außen-Stellplatz;Sicherheitstechnik: Überwachungskamera', 'energy_data': 'Energieträger: Elektro;Heizungsart: Luft-/Wasser-Wärmepumpe;', 'keywords': 'Modernes und zeitloses WohnenIn ansprechender Architektur entstehen 10 individuell geplante Eigentumswohnungen von ca. 84 bis 122 m² Wohnfläche und Garagen im Haus. Ein Stellplatz in der Tiefgarage kann gegen Aufpreis erworben werden. Umweltfreundliche Heizung mit Wärmepumpe, ohne Öl und Gas. 3-Zimmer-Wohnung im EG mit großer Terrasse und Gartenanteil. Bewährte und solide Geiger Bauqualität in Massivbauweise zu fairen Preisen mit Festpreisgarantie. Die Ausführung erfolgt als Effizienzhaus 55.Verwirklichen sie ihren Traum von der eigenen Wohnung als Eigennutzer bzw. sichern sie sich eine wertbeständige Geldanlage als Kapitalanleger. Niedrige Zinsen und günstige Preise ermöglichen ihnen einen guten Kauf zu tätigen. Auf unsere langjährige Erfahrung im schlüsselfertigen Wohnungsbau können sie vertrauen.BesichtigungstermineFür die Zusendung des Exposés bzw. weiterer Informationen zum Objekt bzw. zu den einzelnen Wohnungen, füllen Sie bitte die nachfolgenden Angaben im Kontaktformular aus:- Name- Anschrift- E-Mail Adresse- Telefon - und /oder Mobilnummer Weniger anzeigen '}
# URL: https://www.immowelt.de/expose/285v85b
# {'url': 'https://www.immowelt.de/expose/285v85b', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Gut instand gehaltene 3-Zimmer-Wohnung nebst 2 Balkone', 'price': '200.000\xa0€', 'living_space': '63', 'rooms': '3', 'badges': 'Zwangsversteigerung;Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Gut', 'equipments': 'Na', 'features': 'Na', 'energy_data': '', 'keywords': ' Geschäftszeiten 08:00 - 20:00 Uhr'}
# URL: https://www.immowelt.de/expose/282v85b
# {'url': 'https://www.immowelt.de/expose/282v85b', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': '3-Zimmer-Wohnung im guten Erhaltungszustand', 'price': '230.000\xa0€', 'living_space': '72', 'rooms': '3', 'badges': 'Zwangsversteigerung;Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Gut', 'equipments': 'Wohnungslage: Erdgeschoss', 'features': 'Na', 'energy_data': '', 'keywords': ' Geschäftszeiten 08:00 - 20:00 Uhr'}
# URL: https://www.immowelt.de/expose/28m5y5a
# {'url': 'https://www.immowelt.de/expose/28m5y5a', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Ideale Kapitalanlage im Herzen Ludwigsburgs', 'price': '250.000\xa0€', 'living_space': '46', 'rooms': '2', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Super', 'rating_public_transport': 'Super', 'equipments': 'Wohnungslage: Erdgeschoss;Bezug: vermietet;Derzeitige Nutzung: vermietet', 'features': 'Balkon;Einbauküche;Böden: Laminat;Weitere Räume: Kelleranteil;Baujahr: 1994;1 Stellplatz: Tiefgarage', 'energy_data': 'Energieträger: Gas;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Wesentliche Energieträger: GAS;Gültigkeit:  18.05.2018 bis 17.05.2028 ;Effizienzklasse: D;Endenergieverbrauch:  113,00 kWh/(m²·a)  - Warmwasser enthalten ;', 'keywords': ' Geschäftszeiten Montag bis Freitag von 9:00 bis 18:00 Uhr'}
# URL: https://www.immowelt.de/expose/28qnu5a
# {'url': 'https://www.immowelt.de/expose/28qnu5a', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Wohnen an den Lucianwiesen', 'price': '323.190\xa0€', 'living_space': '79,80', 'rooms': '2', 'badges': 'Provisionsfrei;Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Okay', 'equipments': 'Kategorie: Penthouse', 'features': 'Böden: Fliesenboden, Teppichboden;Zustand: Erstbezug;Baujahr: 2023;Personenaufzug;44 Stellplätze', 'energy_data': 'Energieträger: Elektro, Gas;Heizungsart: Fußbodenheizung, Luft-/Wasser-Wärmepumpe;', 'keywords': ' Geschäftszeiten Mo - Fr.: 09.30 - 12.00 UhrMo, Die: 14.00 - 16.30 UhrDo:14.00 - 17.30 Uhr'}
# URL: https://www.immowelt.de/expose/28lhm5a
# {'url': 'https://www.immowelt.de/expose/28lhm5a', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': '**Sofort beziehbar: Wohntraum auf 2 Ebenen, 149 m² in Calw-Stammheim**', 'price': '479.500\xa0€', 'living_space': '149', 'rooms': '5', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Okay', 'equipments': 'Wohnungslage: 3. Geschoss;Bezug: sofort', 'features': 'Bad mit Fenster, Wanne und Dusche, Gäste-WC;Balkon;Einbauküche;Böden: Fliesenboden;Zustand: gepflegt;Baujahr: 1990;1 Stellplatz', 'energy_data': 'Energieträger: Gas;Heizungsart: Zentralheizung;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 1990;Wesentliche Energieträger: Gas;Gültigkeit:  27.02.2018 bis 27.02.2028 ;Effizienzklasse: F;Endenergieverbrauch:  188,30 kWh/(m²·a)  ;', 'keywords': ' Geschäftszeiten Bürozeiten: täglich 08.00 Uhr bis 16.00 Uhr'}
# URL: https://www.immowelt.de/expose/28gts59
# {'url': 'https://www.immowelt.de/expose/28gts59', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Gemütliche Stadtwohnung für Individualisten', 'price': '207.000\xa0€', 'living_space': '70,48', 'rooms': '2', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Okay', 'equipments': 'Kategorie: Maisonette', 'features': 'Baujahr: 1890', 'energy_data': 'Energieausweistyp: Bedarfsausweis;Gebäudetyp: Wohngebäude;Wesentliche Energieträger: GAS;Gültigkeit:  bis 28.07.2030 ;Effizienzklasse: H;Endenergiebedarf:  338,10 kWh/(m²·a)  ;', 'keywords': ' Geschäftszeiten Mo-Do  08:00 - 12:30             14:00 - 17:00Fr         08:00 - 12:30'}
# URL: https://www.immowelt.de/expose/28lmh5b
# {'url': 'https://www.immowelt.de/expose/28lmh5b', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Wo Ihre Mieter gerne wohnen!', 'price': '176.000\xa0€', 'living_space': '61', 'rooms': '2,5', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Okay', 'rating_public_transport': 'Mäßig', 'equipments': 'Wohnungslage: Dachgeschoss;Derzeitige Nutzung: vermietet', 'features': 'Garten;Baujahr: 1972;2 Stellplätze', 'energy_data': 'Energieträger: Öl;Heizungsart: Zentralheizung;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 1973;Wesentliche Energieträger: Öl;Gültigkeit:  01.12.2022 bis 01.12.2032 ;Effizienzklasse: D;Endenergieverbrauch:  129,20 kWh/(m²·a)  - Warmwasser enthalten ;', 'keywords': 'Garage vorhanden, Stellplatz vorhanden, Bundesland: Baden-Württemberg'}
# URL: https://www.immowelt.de/expose/28sgh59
# {'url': 'https://www.immowelt.de/expose/28sgh59', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': '!!Lage! Ausblick! Wohnung!! **Alles Top. Neckarterrassen Heilbronn**', 'price': '559.000\xa0€', 'living_space': '95', 'rooms': '3,5', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Super', 'equipments': 'Wohnungslage: 3. Geschoss;Bezug: 01.02.2023', 'features': 'Bad mit Fenster und Dusche, Gäste-WC;Balkon;Einbauküche;barrierefrei;Böden: Fliesenboden;Zustand: gepflegt;Weitere Räume: Kelleranteil;Baujahr: 2004;Personenaufzug', 'energy_data': 'Energieträger: Gas;Heizungsart: Zentralheizung;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 2004;Wesentliche Energieträger: Gas;Gültigkeit:  21.06.2018 bis 21.06.2028 ;Effizienzklasse: B;Endenergieverbrauch:  69,00 kWh/(m²·a)  ;', 'keywords': ' Geschäftszeiten Bürozeiten: täglich 08.00 Uhr bis 16.00 Uhr'}
# URL: https://www.immowelt.de/expose/28sm759
# {'url': 'https://www.immowelt.de/expose/28sm759', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'F&D | Gepflegte 2,5-Zimmer-Wohnung mit herrlichem Blick auf Tuttlingen', 'price': '238.000\xa0€', 'living_space': '88', 'rooms': '2,5', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Okay', 'equipments': 'Wohnungslage: 3. Geschoss;Bezug: ab sofort', 'features': 'Loggia;Ausblick: Fernblick;Böden: Parkett;Zustand: gepflegt;Baujahr: 1983;1 Stellplatz: Garage', 'energy_data': 'Energieträger: Gas;Heizungsart: Zentralheizung;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 1983;Wesentliche Energieträger: Gas;Effizienzklasse: E;Endenergieverbrauch:  140,00 kWh/(m²·a)  ;', 'keywords': ' Geschäftszeiten Mo - Fr   8.30 - 18.00 Uhr und nach Terminvereinbarung'}
# URL: https://www.immowelt.de/expose/288rt58
# {'url': 'https://www.immowelt.de/expose/288rt58', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Schöne 3 Zimmer-Küche-Bad-Wohnung mit Balkon in Laudenbach', 'price': '165.000\xa0€', 'living_space': '65', 'rooms': '3', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Okay', 'rating_public_transport': 'Okay', 'equipments': 'Wohnungslage: 2. Geschoss;Derzeitige Nutzung: vermietet', 'features': 'Bad mit Wanne;Balkon;Ausblick: Fernblick;Böden: Fliesenboden, Teppichboden;Fenster: Kunststofffenster;Zustand: gepflegt;Weitere Räume: Kelleranteil, Wasch-Trockenraum;Anschlüsse: DSL-Anschluss;Baujahr: 1983;1 Stellplatz', 'energy_data': 'Energieträger: Fernwärme, Öl;Heizungsart: Zentralheizung;', 'keywords': 'TV: Kabelanschluss, Sat-Anschluss, Antennenanschluss, DVBTVersorgung: Eigene Wasserversorgung, RegenwassernutzungSonstiges: ISDN, Analog'}
# URL: https://www.immowelt.de/expose/28y2q58
# {'url': 'https://www.immowelt.de/expose/28y2q58', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': '1 Zi. ETW in Oberesslingen', 'price': '110.000\xa0€', 'living_space': '28', 'rooms': '1', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Super', 'equipments': 'Derzeitige Nutzung: vermietet', 'features': 'Balkon;Zustand: gepflegt;Baujahr: 1968', 'energy_data': 'Energieträger: Elektro;Heizungsart: Ofen;Energieausweistyp: Bedarfsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 1964;Wesentliche Energieträger: Elektroenergie;Gültigkeit:  06.12.2022 bis 05.12.2032 ;Effizienzklasse: D;Endenergiebedarf:  124,10 kWh/(m²·a)  ;', 'keywords': 'Anzahl der Schlafzimmer: 1, Anzahl der Badezimmer: 1, Anzahl Balkone: 1, Bundesland: Baden-Württemberg, modernisiert: 2012'}
# URL: https://www.immowelt.de/expose/28uu458
# {'url': 'https://www.immowelt.de/expose/28uu458', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Allein oder zu zweit - einziehen oder doch vermieten?', 'price': '229.000\xa0€', 'living_space': '56,56', 'rooms': '2', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Okay', 'rating_public_transport': 'Gut', 'equipments': 'Na', 'features': 'Terrasse;Einbauküche;Baujahr: 1986', 'energy_data': 'Energieträger: Fernwärme;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 1986;Wesentliche Energieträger: Fernwärme;Gültigkeit:  bis 02.11.2027 ;Effizienzklasse: C;Endenergieverbrauch:  96,00 kWh/(m²·a)  - Warmwasser enthalten ;', 'keywords': ' Geschäftszeiten Montag-Freitag 8 - 18 UhrSamstag     10:30 - 12:30 UhrOder nach individueller Vereinbarung.'}
# URL: https://www.immowelt.de/expose/28xs85b
# {'url': 'https://www.immowelt.de/expose/28xs85b', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': '2-Zimmer-Wohnung mit schönem Putzbalkon - provisionsfrei', 'price': '249.000\xa0€', 'living_space': '56', 'rooms': '2', 'badges': 'Zwangsversteigerung;Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Super', 'equipments': 'Na', 'features': 'Na', 'energy_data': '', 'keywords': ' Geschäftszeiten 08:00 - 20:00 Uhr'}
# URL: https://www.immowelt.de/expose/28fvq57
# {'url': 'https://www.immowelt.de/expose/28fvq57', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Perfekte Lage mit Ausblick in liebevoller Dachgeschosswohnung in Tiengen', 'price': '275.000\xa0€', 'living_space': '88', 'rooms': '3,5', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Super', 'rating_public_transport': 'Okay', 'equipments': 'Wohnungslage: Dachgeschoss;Bezug: 01.03.2023', 'features': 'Balkon;Zustand: gepflegt;Anschlüsse: Kabelanschluss;Baujahr: 1982;1 Stellplatz: Garage', 'energy_data': 'Energieträger: Gas;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 1982;Wesentliche Energieträger: GAS;Gültigkeit:  bis 14.11.2031 ;Effizienzklasse: D;Endenergieverbrauch:  105,00 kWh/(m²·a)  - Warmwasser enthalten ;', 'keywords': ' Geschäftszeiten Mo. - Fr. von 09:00 - 12:00 Uhr (Bürozeit)Telefonisch von 08:00 - 20:00 Uhr'}
# [2022-12-23, 07:51:25] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 2 of 30
# URL: https://www.immowelt.de/expose/28xsk53
# {'url': 'https://www.immowelt.de/expose/28xsk53', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'TIENGEN: 3,5-Zimmer-Obergeschosswohnung incl. großem Kellerraum und 2 Tiefgaragenstellplätze.', 'price': '320.000\xa0€', 'living_space': '87', 'rooms': '3,5', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Okay', 'equipments': 'Wohnungslage: 2. Geschoss;Bezug: Nach Vereinbarung!', 'features': 'Balkon;Zustand: gepflegt;Weitere Räume: Kelleranteil;Baujahr: 1995', 'energy_data': 'Heizungsart: Fußbodenheizung;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 1995;Wesentliche Energieträger: GAS;Gültigkeit:  bis 24.11.2018 ;Effizienzklasse: H;Endenergieverbrauch:  170,10 kWh/(m²·a)  - Warmwasser enthalten ;', 'keywords': 'Nutzfläche: 12,00 m², Anzahl der Schlafzimmer: 2, Anzahl der Badezimmer: 1, Anzahl der separaten WCs: 1, Anzahl Balkone: 1, 4 Etagen, Distanz zum Kindergarten: 0.50, Distanz zur Grundschule: 0.50, Distanz zur Realschule: 1.00, Distanz zum Gymnasium: 1.00, Distanz zur Autobahn: 35.00, Distanz vom Zentrum: 0.30 Weniger anzeigen'}
# URL: https://www.immowelt.de/expose/27egy5v
# {'url': 'https://www.immowelt.de/expose/27egy5v', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Investmentchance im Herzen von Konstanz - vergünstigter Preis - Text beachten', 'price': '449.500\xa0€', 'living_space': '79', 'rooms': '2,5', 'badges': 'Provisionsfrei;Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Super', 'equipments': 'Wohnungslage: 2. Geschoss;Bezug: vermietet;Derzeitige Nutzung: vermietet', 'features': 'Bad mit Fenster, Wanne und Dusche;Loggia;Zustand: renovierungsbedürftig / sanierungsbedürftig;Weitere Räume: Kelleranteil;Baujahr: 1998;Personenaufzug', 'energy_data': 'Energieträger: Gas;Heizungsart: Zentralheizung;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 2000;Wesentliche Energieträger: Gas;Gültigkeit:  07.03.2014 bis 06.03.2024 ;Endenergieverbrauch:  95,00 kWh/(m²·a)  - Warmwasser enthalten ;', 'keywords': 'Versorgung: Städtische Wasserversorgung, Städtische StromversorgungServiceleistungen: Hausmeister Weniger anzeigen'}
# URL: https://www.immowelt.de/expose/27dc45u
# {'url': 'https://www.immowelt.de/expose/27dc45u', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Neubau-Erstbezug Eigentumswohnungen', 'price': '465.000\xa0€', 'living_space': '53,99', 'rooms': '2', 'badges': 'Provisionsfrei;Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Gut', 'equipments': 'Kategorie: Terrassenwohnung;Bezug: 2023', 'features': 'Terrasse;Böden: Fliesenboden;Zustand: Erstbezug;Baujahr: 2023;Zustand: Neubau;Personenaufzug;1 Stellplatz: Tiefgarage', 'energy_data': 'Energieträger: Gas;Haustyp: KfW 55;Heizungsart: Luft-/Wasser-Wärmepumpe;', 'keywords': ' Geschäftszeiten Beratungstermine nach Vereinbarung'}
# URL: https://www.immowelt.de/expose/28b5m5a
# {'url': 'https://www.immowelt.de/expose/28b5m5a', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': '**Sofort bezugsfrei** Terrasse + Garten', 'price': '179.000\xa0€', 'living_space': '58,35', 'rooms': '2', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Gut', 'equipments': 'Bezug: sofort', 'features': 'Baujahr: 1900', 'energy_data': 'Energieträger: Öl;Heizungsart: Zentralheizung;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 1900;Wesentliche Energieträger: OEL;Gültigkeit:  06.02.2022 bis 05.02.2032 ;Endenergieverbrauch:  154,20 kWh/(m²·a)  - Warmwasser enthalten ;', 'keywords': 'Nutzfläche: 5,00 m², Grundstücksfläche: 957,00 m², Anzahl der Schlafzimmer: 1, Anzahl der Badezimmer: 1, Balkon-Terrassen-Fläche: 6,00 m², Anzahl der Wohneinheiten: 10 Weniger anzeigen'}
# URL: https://www.immowelt.de/expose/2zpe54x
# {'url': 'https://www.immowelt.de/expose/2zpe54x', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Neue Wohnungen in Durbach-Ebersweier. Hier Wohnung 5 im DG. Baubeginn Januar 2021 und Fertigstellung Ende 2021', 'price': '385.000\xa0€', 'living_space': 'Na', 'rooms': '4', 'badges': 'Provisionsfrei;Gewerblicher Anbieter', 'rating_location': 'Okay', 'rating_public_transport': 'Okay', 'equipments': 'Wohnungslage: Dachgeschoss;Bezug: 2021', 'features': 'Balkon;Fenster: Kunststofffenster;Baujahr: 2021;Stellplätze: Garage, Außen-Stellplatz', 'energy_data': 'Energieträger: Blockheizkraftwerk, Gas;Heizungsart: Fußbodenheizung;Gebäudetyp: Wohngebäude;', 'keywords': 'ObjekteSechs Wohnungen mit vier Zimmern in einem Mehrfamilienhaus. Je nach Baufortschritt besteht noch die Möglichkeit den Grundriss anzupassen..InformationenFür die Erdgeschosswohnungen besteht ein Sondernutzungsrecht am östlichen Grünstreifen der jeweiligen Wohnung.Weitere Informationen gern vorab unter 0781-9705144.KonzeptDie Fassaden der Gesamtanlage bekommen ein Farbkonzept mit gedeckten Farben die sich innerhalb der Anlage wiederholen. Jedes Haus hat aber eine andere Zusammensetzung der Farben. Die Farben können im Original in unserem Büro gezeigt werden.Beheizt wird die Gesamtanlage über ein Blockheizkraftwerk. Dieses erzeugt auch Strom welcher in das Netz wieder eingespeist wird und der Gemeinschaft gut geschrieben wird.BarrierefreiheitBarrierefrei sind die zwei Erdgeschosswohnungen im Mehrfamilienhaus konzipiert.Vorteil ist hierbei dass kein Aufzug für die barrierfreiheit nötig ist - was die Gemeinkosten in Grenzen hält.Gegebenenfalls lässt sich ein Treppenlift z.B. Lifta auch nachträglich einbauen. Weniger anzeigen '}
# URL: https://www.immowelt.de/expose/242tu5x
# {'url': 'https://www.immowelt.de/expose/242tu5x', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Wohnung Nr. 1 "Wohnen unter der Schleicherhütte" Flandernstraße Albstadt-Ebingen', 'price': '316.500\xa0€', 'living_space': '83,67', 'rooms': '3', 'badges': 'Provisionsfrei;Gewerblicher Anbieter', 'rating_location': 'Okay', 'rating_public_transport': 'Okay', 'equipments': 'Wohnungslage: Erdgeschoss', 'features': 'Bad mit Fenster, Wanne und Dusche, Gäste-WC;Terrasse;Ausblick: Fernblick;offene Küche;Böden: Fliesenboden, Parkett;Fenster: Kunststofffenster;Zustand: Erstbezug;Weitere Räume: Kelleranteil, Wasch-Trockenraum;Anschlüsse: Satellitenanschluss;Baujahr: 2022;Zustand: Neubau;Personenaufzug;Stellplätze: Garage, Außen-Stellplatz;Sicherheitstechnik: Überwachungskamera', 'energy_data': 'Energieträger: Elektro;Heizungsart: Luft-/Wasser-Wärmepumpe;', 'keywords': 'Modernes und zeitloses WohnenIn ansprechender Architektur entstehen 10 individuell geplante Eigentumswohnungen von ca. 84 bis 122 m² Wohnfläche und Garagen im Haus. Ein Stellplatz in der Tiefgarage kann gegen Aufpreis erworben werden. Umweltfreundliche Heizung mit Wärmepumpe, ohne Öl und Gas. 3-Zimmer-Wohnung im EG mit großer Terrasse und Gartenanteil. Bewährte und solide Geiger Bauqualität in Massivbauweise zu fairen Preisen mit Festpreisgarantie. Die Ausführung erfolgt als Effizienzhaus 55.Verwirklichen sie ihren Traum von der eigenen Wohnung als Eigennutzer bzw. sichern sie sich eine wertbeständige Geldanlage als Kapitalanleger. Niedrige Zinsen und günstige Preise ermöglichen ihnen einen guten Kauf zu tätigen. Auf unsere langjährige Erfahrung im schlüsselfertigen Wohnungsbau können sie vertrauen.BesichtigungstermineFür die Zusendung des Exposés bzw. weiterer Informationen zum Objekt bzw. zu den einzelnen Wohnungen, füllen Sie bitte die nachfolgenden Angaben im Kontaktformular aus:- Name- Anschrift- E-Mail Adresse- Telefon - und /oder Mobilnummer Weniger anzeigen '}
# URL: https://www.immowelt.de/expose/285v85b
# {'url': 'https://www.immowelt.de/expose/285v85b', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Gut instand gehaltene 3-Zimmer-Wohnung nebst 2 Balkone', 'price': '200.000\xa0€', 'living_space': '63', 'rooms': '3', 'badges': 'Zwangsversteigerung;Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Gut', 'equipments': 'Na', 'features': 'Na', 'energy_data': '', 'keywords': ' Geschäftszeiten 08:00 - 20:00 Uhr'}
# URL: https://www.immowelt.de/expose/282v85b
# {'url': 'https://www.immowelt.de/expose/282v85b', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': '3-Zimmer-Wohnung im guten Erhaltungszustand', 'price': '230.000\xa0€', 'living_space': '72', 'rooms': '3', 'badges': 'Zwangsversteigerung;Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Gut', 'equipments': 'Wohnungslage: Erdgeschoss', 'features': 'Na', 'energy_data': '', 'keywords': ' Geschäftszeiten 08:00 - 20:00 Uhr'}
# URL: https://www.immowelt.de/expose/28m5y5a
# {'url': 'https://www.immowelt.de/expose/28m5y5a', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Ideale Kapitalanlage im Herzen Ludwigsburgs', 'price': '250.000\xa0€', 'living_space': '46', 'rooms': '2', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Super', 'rating_public_transport': 'Super', 'equipments': 'Wohnungslage: Erdgeschoss;Bezug: vermietet;Derzeitige Nutzung: vermietet', 'features': 'Balkon;Einbauküche;Böden: Laminat;Weitere Räume: Kelleranteil;Baujahr: 1994;1 Stellplatz: Tiefgarage', 'energy_data': 'Energieträger: Gas;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Wesentliche Energieträger: GAS;Gültigkeit:  18.05.2018 bis 17.05.2028 ;Effizienzklasse: D;Endenergieverbrauch:  113,00 kWh/(m²·a)  - Warmwasser enthalten ;', 'keywords': ' Geschäftszeiten Montag bis Freitag von 9:00 bis 18:00 Uhr'}
# URL: https://www.immowelt.de/expose/28qnu5a
# {'url': 'https://www.immowelt.de/expose/28qnu5a', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Wohnen an den Lucianwiesen', 'price': '323.190\xa0€', 'living_space': '79,80', 'rooms': '2', 'badges': 'Provisionsfrei;Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Okay', 'equipments': 'Kategorie: Penthouse', 'features': 'Böden: Fliesenboden, Teppichboden;Zustand: Erstbezug;Baujahr: 2023;Personenaufzug;44 Stellplätze', 'energy_data': 'Energieträger: Elektro, Gas;Heizungsart: Fußbodenheizung, Luft-/Wasser-Wärmepumpe;', 'keywords': ' Geschäftszeiten Mo - Fr.: 09.30 - 12.00 UhrMo, Die: 14.00 - 16.30 UhrDo:14.00 - 17.30 Uhr'}
# URL: https://www.immowelt.de/expose/28lhm5a
# {'url': 'https://www.immowelt.de/expose/28lhm5a', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': '**Sofort beziehbar: Wohntraum auf 2 Ebenen, 149 m² in Calw-Stammheim**', 'price': '479.500\xa0€', 'living_space': '149', 'rooms': '5', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Okay', 'equipments': 'Wohnungslage: 3. Geschoss;Bezug: sofort', 'features': 'Bad mit Fenster, Wanne und Dusche, Gäste-WC;Balkon;Einbauküche;Böden: Fliesenboden;Zustand: gepflegt;Baujahr: 1990;1 Stellplatz', 'energy_data': 'Energieträger: Gas;Heizungsart: Zentralheizung;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 1990;Wesentliche Energieträger: Gas;Gültigkeit:  27.02.2018 bis 27.02.2028 ;Effizienzklasse: F;Endenergieverbrauch:  188,30 kWh/(m²·a)  ;', 'keywords': ' Geschäftszeiten Bürozeiten: täglich 08.00 Uhr bis 16.00 Uhr'}
# URL: https://www.immowelt.de/expose/28gts59
# {'url': 'https://www.immowelt.de/expose/28gts59', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Gemütliche Stadtwohnung für Individualisten', 'price': '207.000\xa0€', 'living_space': '70,48', 'rooms': '2', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Okay', 'equipments': 'Kategorie: Maisonette', 'features': 'Baujahr: 1890', 'energy_data': 'Energieausweistyp: Bedarfsausweis;Gebäudetyp: Wohngebäude;Wesentliche Energieträger: GAS;Gültigkeit:  bis 28.07.2030 ;Effizienzklasse: H;Endenergiebedarf:  338,10 kWh/(m²·a)  ;', 'keywords': ' Geschäftszeiten Mo-Do  08:00 - 12:30             14:00 - 17:00Fr         08:00 - 12:30'}
# URL: https://www.immowelt.de/expose/28lmh5b
# {'url': 'https://www.immowelt.de/expose/28lmh5b', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Wo Ihre Mieter gerne wohnen!', 'price': '176.000\xa0€', 'living_space': '61', 'rooms': '2,5', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Okay', 'rating_public_transport': 'Mäßig', 'equipments': 'Wohnungslage: Dachgeschoss;Derzeitige Nutzung: vermietet', 'features': 'Garten;Baujahr: 1972;2 Stellplätze', 'energy_data': 'Energieträger: Öl;Heizungsart: Zentralheizung;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 1973;Wesentliche Energieträger: Öl;Gültigkeit:  01.12.2022 bis 01.12.2032 ;Effizienzklasse: D;Endenergieverbrauch:  129,20 kWh/(m²·a)  - Warmwasser enthalten ;', 'keywords': 'Garage vorhanden, Stellplatz vorhanden, Bundesland: Baden-Württemberg'}
# URL: https://www.immowelt.de/expose/28sgh59
# {'url': 'https://www.immowelt.de/expose/28sgh59', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': '!!Lage! Ausblick! Wohnung!! **Alles Top. Neckarterrassen Heilbronn**', 'price': '559.000\xa0€', 'living_space': '95', 'rooms': '3,5', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Super', 'equipments': 'Wohnungslage: 3. Geschoss;Bezug: 01.02.2023', 'features': 'Bad mit Fenster und Dusche, Gäste-WC;Balkon;Einbauküche;barrierefrei;Böden: Fliesenboden;Zustand: gepflegt;Weitere Räume: Kelleranteil;Baujahr: 2004;Personenaufzug', 'energy_data': 'Energieträger: Gas;Heizungsart: Zentralheizung;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 2004;Wesentliche Energieträger: Gas;Gültigkeit:  21.06.2018 bis 21.06.2028 ;Effizienzklasse: B;Endenergieverbrauch:  69,00 kWh/(m²·a)  ;', 'keywords': ' Geschäftszeiten Bürozeiten: täglich 08.00 Uhr bis 16.00 Uhr'}
# URL: https://www.immowelt.de/expose/28sm759
# {'url': 'https://www.immowelt.de/expose/28sm759', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'F&D | Gepflegte 2,5-Zimmer-Wohnung mit herrlichem Blick auf Tuttlingen', 'price': '238.000\xa0€', 'living_space': '88', 'rooms': '2,5', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Okay', 'equipments': 'Wohnungslage: 3. Geschoss;Bezug: ab sofort', 'features': 'Loggia;Ausblick: Fernblick;Böden: Parkett;Zustand: gepflegt;Baujahr: 1983;1 Stellplatz: Garage', 'energy_data': 'Energieträger: Gas;Heizungsart: Zentralheizung;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 1983;Wesentliche Energieträger: Gas;Effizienzklasse: E;Endenergieverbrauch:  140,00 kWh/(m²·a)  ;', 'keywords': ' Geschäftszeiten Mo - Fr   8.30 - 18.00 Uhr und nach Terminvereinbarung'}
# URL: https://www.immowelt.de/expose/288rt58
# {'url': 'https://www.immowelt.de/expose/288rt58', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Schöne 3 Zimmer-Küche-Bad-Wohnung mit Balkon in Laudenbach', 'price': '165.000\xa0€', 'living_space': '65', 'rooms': '3', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Okay', 'rating_public_transport': 'Okay', 'equipments': 'Wohnungslage: 2. Geschoss;Derzeitige Nutzung: vermietet', 'features': 'Bad mit Wanne;Balkon;Ausblick: Fernblick;Böden: Fliesenboden, Teppichboden;Fenster: Kunststofffenster;Zustand: gepflegt;Weitere Räume: Kelleranteil, Wasch-Trockenraum;Anschlüsse: DSL-Anschluss;Baujahr: 1983;1 Stellplatz', 'energy_data': 'Energieträger: Fernwärme, Öl;Heizungsart: Zentralheizung;', 'keywords': 'TV: Kabelanschluss, Sat-Anschluss, Antennenanschluss, DVBTVersorgung: Eigene Wasserversorgung, RegenwassernutzungSonstiges: ISDN, Analog'}
# URL: https://www.immowelt.de/expose/28y2q58
# {'url': 'https://www.immowelt.de/expose/28y2q58', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': '1 Zi. ETW in Oberesslingen', 'price': '110.000\xa0€', 'living_space': '28', 'rooms': '1', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Super', 'equipments': 'Derzeitige Nutzung: vermietet', 'features': 'Balkon;Zustand: gepflegt;Baujahr: 1968', 'energy_data': 'Energieträger: Elektro;Heizungsart: Ofen;Energieausweistyp: Bedarfsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 1964;Wesentliche Energieträger: Elektroenergie;Gültigkeit:  06.12.2022 bis 05.12.2032 ;Effizienzklasse: D;Endenergiebedarf:  124,10 kWh/(m²·a)  ;', 'keywords': 'Anzahl der Schlafzimmer: 1, Anzahl der Badezimmer: 1, Anzahl Balkone: 1, Bundesland: Baden-Württemberg, modernisiert: 2012'}
# URL: https://www.immowelt.de/expose/28uu458
# {'url': 'https://www.immowelt.de/expose/28uu458', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Allein oder zu zweit - einziehen oder doch vermieten?', 'price': '229.000\xa0€', 'living_space': '56,56', 'rooms': '2', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Okay', 'rating_public_transport': 'Gut', 'equipments': 'Na', 'features': 'Terrasse;Einbauküche;Baujahr: 1986', 'energy_data': 'Energieträger: Fernwärme;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 1986;Wesentliche Energieträger: Fernwärme;Gültigkeit:  bis 02.11.2027 ;Effizienzklasse: C;Endenergieverbrauch:  96,00 kWh/(m²·a)  - Warmwasser enthalten ;', 'keywords': ' Geschäftszeiten Montag-Freitag 8 - 18 UhrSamstag     10:30 - 12:30 UhrOder nach individueller Vereinbarung.'}
# URL: https://www.immowelt.de/expose/28xs85b
# {'url': 'https://www.immowelt.de/expose/28xs85b', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': '2-Zimmer-Wohnung mit schönem Putzbalkon - provisionsfrei', 'price': '249.000\xa0€', 'living_space': '56', 'rooms': '2', 'badges': 'Zwangsversteigerung;Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Super', 'equipments': 'Na', 'features': 'Na', 'energy_data': '', 'keywords': ' Geschäftszeiten 08:00 - 20:00 Uhr'}
# URL: https://www.immowelt.de/expose/28fvq57
# {'url': 'https://www.immowelt.de/expose/28fvq57', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Perfekte Lage mit Ausblick in liebevoller Dachgeschosswohnung in Tiengen', 'price': '275.000\xa0€', 'living_space': '88', 'rooms': '3,5', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Super', 'rating_public_transport': 'Okay', 'equipments': 'Wohnungslage: Dachgeschoss;Bezug: 01.03.2023', 'features': 'Balkon;Zustand: gepflegt;Anschlüsse: Kabelanschluss;Baujahr: 1982;1 Stellplatz: Garage', 'energy_data': 'Energieträger: Gas;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 1982;Wesentliche Energieträger: GAS;Gültigkeit:  bis 14.11.2031 ;Effizienzklasse: D;Endenergieverbrauch:  105,00 kWh/(m²·a)  - Warmwasser enthalten ;', 'keywords': ' Geschäftszeiten Mo. - Fr. von 09:00 - 12:00 Uhr (Bürozeit)Telefonisch von 08:00 - 20:00 Uhr'}
# [2022-12-23, 07:51:42] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 3 of 30
# URL: https://www.immowelt.de/expose/28xsk53
# {'url': 'https://www.immowelt.de/expose/28xsk53', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'TIENGEN: 3,5-Zimmer-Obergeschosswohnung incl. großem Kellerraum und 2 Tiefgaragenstellplätze.', 'price': '320.000\xa0€', 'living_space': '87', 'rooms': '3,5', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Okay', 'equipments': 'Wohnungslage: 2. Geschoss;Bezug: Nach Vereinbarung!', 'features': 'Balkon;Zustand: gepflegt;Weitere Räume: Kelleranteil;Baujahr: 1995', 'energy_data': 'Heizungsart: Fußbodenheizung;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 1995;Wesentliche Energieträger: GAS;Gültigkeit:  bis 24.11.2018 ;Effizienzklasse: H;Endenergieverbrauch:  170,10 kWh/(m²·a)  - Warmwasser enthalten ;', 'keywords': 'Nutzfläche: 12,00 m², Anzahl der Schlafzimmer: 2, Anzahl der Badezimmer: 1, Anzahl der separaten WCs: 1, Anzahl Balkone: 1, 4 Etagen, Distanz zum Kindergarten: 0.50, Distanz zur Grundschule: 0.50, Distanz zur Realschule: 1.00, Distanz zum Gymnasium: 1.00, Distanz zur Autobahn: 35.00, Distanz vom Zentrum: 0.30 Weniger anzeigen'}
# URL: https://www.immowelt.de/expose/27egy5v
# {'url': 'https://www.immowelt.de/expose/27egy5v', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Investmentchance im Herzen von Konstanz - vergünstigter Preis - Text beachten', 'price': '449.500\xa0€', 'living_space': '79', 'rooms': '2,5', 'badges': 'Provisionsfrei;Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Super', 'equipments': 'Wohnungslage: 2. Geschoss;Bezug: vermietet;Derzeitige Nutzung: vermietet', 'features': 'Bad mit Fenster, Wanne und Dusche;Loggia;Zustand: renovierungsbedürftig / sanierungsbedürftig;Weitere Räume: Kelleranteil;Baujahr: 1998;Personenaufzug', 'energy_data': 'Energieträger: Gas;Heizungsart: Zentralheizung;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 2000;Wesentliche Energieträger: Gas;Gültigkeit:  07.03.2014 bis 06.03.2024 ;Endenergieverbrauch:  95,00 kWh/(m²·a)  - Warmwasser enthalten ;', 'keywords': 'Versorgung: Städtische Wasserversorgung, Städtische StromversorgungServiceleistungen: Hausmeister Weniger anzeigen'}
# URL: https://www.immowelt.de/expose/27dc45u
# {'url': 'https://www.immowelt.de/expose/27dc45u', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Neubau-Erstbezug Eigentumswohnungen', 'price': '465.000\xa0€', 'living_space': '53,99', 'rooms': '2', 'badges': 'Provisionsfrei;Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Gut', 'equipments': 'Kategorie: Terrassenwohnung;Bezug: 2023', 'features': 'Terrasse;Böden: Fliesenboden;Zustand: Erstbezug;Baujahr: 2023;Zustand: Neubau;Personenaufzug;1 Stellplatz: Tiefgarage', 'energy_data': 'Energieträger: Gas;Haustyp: KfW 55;Heizungsart: Luft-/Wasser-Wärmepumpe;', 'keywords': ' Geschäftszeiten Beratungstermine nach Vereinbarung'}
# URL: https://www.immowelt.de/expose/28b5m5a
# {'url': 'https://www.immowelt.de/expose/28b5m5a', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': '**Sofort bezugsfrei** Terrasse + Garten', 'price': '179.000\xa0€', 'living_space': '58,35', 'rooms': '2', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Gut', 'equipments': 'Bezug: sofort', 'features': 'Baujahr: 1900', 'energy_data': 'Energieträger: Öl;Heizungsart: Zentralheizung;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 1900;Wesentliche Energieträger: OEL;Gültigkeit:  06.02.2022 bis 05.02.2032 ;Endenergieverbrauch:  154,20 kWh/(m²·a)  - Warmwasser enthalten ;', 'keywords': 'Nutzfläche: 5,00 m², Grundstücksfläche: 957,00 m², Anzahl der Schlafzimmer: 1, Anzahl der Badezimmer: 1, Balkon-Terrassen-Fläche: 6,00 m², Anzahl der Wohneinheiten: 10 Weniger anzeigen'}
# URL: https://www.immowelt.de/expose/2zpe54x
# {'url': 'https://www.immowelt.de/expose/2zpe54x', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Neue Wohnungen in Durbach-Ebersweier. Hier Wohnung 5 im DG. Baubeginn Januar 2021 und Fertigstellung Ende 2021', 'price': '385.000\xa0€', 'living_space': 'Na', 'rooms': '4', 'badges': 'Provisionsfrei;Gewerblicher Anbieter', 'rating_location': 'Okay', 'rating_public_transport': 'Okay', 'equipments': 'Wohnungslage: Dachgeschoss;Bezug: 2021', 'features': 'Balkon;Fenster: Kunststofffenster;Baujahr: 2021;Stellplätze: Garage, Außen-Stellplatz', 'energy_data': 'Energieträger: Blockheizkraftwerk, Gas;Heizungsart: Fußbodenheizung;Gebäudetyp: Wohngebäude;', 'keywords': 'ObjekteSechs Wohnungen mit vier Zimmern in einem Mehrfamilienhaus. Je nach Baufortschritt besteht noch die Möglichkeit den Grundriss anzupassen..InformationenFür die Erdgeschosswohnungen besteht ein Sondernutzungsrecht am östlichen Grünstreifen der jeweiligen Wohnung.Weitere Informationen gern vorab unter 0781-9705144.KonzeptDie Fassaden der Gesamtanlage bekommen ein Farbkonzept mit gedeckten Farben die sich innerhalb der Anlage wiederholen. Jedes Haus hat aber eine andere Zusammensetzung der Farben. Die Farben können im Original in unserem Büro gezeigt werden.Beheizt wird die Gesamtanlage über ein Blockheizkraftwerk. Dieses erzeugt auch Strom welcher in das Netz wieder eingespeist wird und der Gemeinschaft gut geschrieben wird.BarrierefreiheitBarrierefrei sind die zwei Erdgeschosswohnungen im Mehrfamilienhaus konzipiert.Vorteil ist hierbei dass kein Aufzug für die barrierfreiheit nötig ist - was die Gemeinkosten in Grenzen hält.Gegebenenfalls lässt sich ein Treppenlift z.B. Lifta auch nachträglich einbauen. Weniger anzeigen '}
# URL: https://www.immowelt.de/expose/242tu5x
# {'url': 'https://www.immowelt.de/expose/242tu5x', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Wohnung Nr. 1 "Wohnen unter der Schleicherhütte" Flandernstraße Albstadt-Ebingen', 'price': '316.500\xa0€', 'living_space': '83,67', 'rooms': '3', 'badges': 'Provisionsfrei;Gewerblicher Anbieter', 'rating_location': 'Okay', 'rating_public_transport': 'Okay', 'equipments': 'Wohnungslage: Erdgeschoss', 'features': 'Bad mit Fenster, Wanne und Dusche, Gäste-WC;Terrasse;Ausblick: Fernblick;offene Küche;Böden: Fliesenboden, Parkett;Fenster: Kunststofffenster;Zustand: Erstbezug;Weitere Räume: Kelleranteil, Wasch-Trockenraum;Anschlüsse: Satellitenanschluss;Baujahr: 2022;Zustand: Neubau;Personenaufzug;Stellplätze: Garage, Außen-Stellplatz;Sicherheitstechnik: Überwachungskamera', 'energy_data': 'Energieträger: Elektro;Heizungsart: Luft-/Wasser-Wärmepumpe;', 'keywords': 'Modernes und zeitloses WohnenIn ansprechender Architektur entstehen 10 individuell geplante Eigentumswohnungen von ca. 84 bis 122 m² Wohnfläche und Garagen im Haus. Ein Stellplatz in der Tiefgarage kann gegen Aufpreis erworben werden. Umweltfreundliche Heizung mit Wärmepumpe, ohne Öl und Gas. 3-Zimmer-Wohnung im EG mit großer Terrasse und Gartenanteil. Bewährte und solide Geiger Bauqualität in Massivbauweise zu fairen Preisen mit Festpreisgarantie. Die Ausführung erfolgt als Effizienzhaus 55.Verwirklichen sie ihren Traum von der eigenen Wohnung als Eigennutzer bzw. sichern sie sich eine wertbeständige Geldanlage als Kapitalanleger. Niedrige Zinsen und günstige Preise ermöglichen ihnen einen guten Kauf zu tätigen. Auf unsere langjährige Erfahrung im schlüsselfertigen Wohnungsbau können sie vertrauen.BesichtigungstermineFür die Zusendung des Exposés bzw. weiterer Informationen zum Objekt bzw. zu den einzelnen Wohnungen, füllen Sie bitte die nachfolgenden Angaben im Kontaktformular aus:- Name- Anschrift- E-Mail Adresse- Telefon - und /oder Mobilnummer Weniger anzeigen '}
# URL: https://www.immowelt.de/expose/285v85b
# {'url': 'https://www.immowelt.de/expose/285v85b', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Gut instand gehaltene 3-Zimmer-Wohnung nebst 2 Balkone', 'price': '200.000\xa0€', 'living_space': '63', 'rooms': '3', 'badges': 'Zwangsversteigerung;Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Gut', 'equipments': 'Na', 'features': 'Na', 'energy_data': '', 'keywords': ' Geschäftszeiten 08:00 - 20:00 Uhr'}
# URL: https://www.immowelt.de/expose/282v85b
# ...
# URL: https://www.immowelt.de/expose/242tu5x
# {'url': 'https://www.immowelt.de/expose/242tu5x', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Wohnung Nr. 1 "Wohnen unter der Schleicherhütte" Flandernstraße Albstadt-Ebingen', 'price': '316.500\xa0€', 'living_space': '83,67', 'rooms': '3', 'badges': 'Provisionsfrei;Gewerblicher Anbieter', 'rating_location': 'Okay', 'rating_public_transport': 'Okay', 'equipments': 'Wohnungslage: Erdgeschoss', 'features': 'Bad mit Fenster, Wanne und Dusche, Gäste-WC;Terrasse;Ausblick: Fernblick;offene Küche;Böden: Fliesenboden, Parkett;Fenster: Kunststofffenster;Zustand: Erstbezug;Weitere Räume: Kelleranteil, Wasch-Trockenraum;Anschlüsse: Satellitenanschluss;Baujahr: 2022;Zustand: Neubau;Personenaufzug;Stellplätze: Garage, Außen-Stellplatz;Sicherheitstechnik: Überwachungskamera', 'energy_data': 'Energieträger: Elektro;Heizungsart: Luft-/Wasser-Wärmepumpe;', 'keywords': 'Modernes und zeitloses WohnenIn ansprechender Architektur entstehen 10 individuell geplante Eigentumswohnungen von ca. 84 bis 122 m² Wohnfläche und Garagen im Haus. Ein Stellplatz in der Tiefgarage kann gegen Aufpreis erworben werden. Umweltfreundliche Heizung mit Wärmepumpe, ohne Öl und Gas. 3-Zimmer-Wohnung im EG mit großer Terrasse und Gartenanteil. Bewährte und solide Geiger Bauqualität in Massivbauweise zu fairen Preisen mit Festpreisgarantie. Die Ausführung erfolgt als Effizienzhaus 55.Verwirklichen sie ihren Traum von der eigenen Wohnung als Eigennutzer bzw. sichern sie sich eine wertbeständige Geldanlage als Kapitalanleger. Niedrige Zinsen und günstige Preise ermöglichen ihnen einen guten Kauf zu tätigen. Auf unsere langjährige Erfahrung im schlüsselfertigen Wohnungsbau können sie vertrauen.BesichtigungstermineFür die Zusendung des Exposés bzw. weiterer Informationen zum Objekt bzw. zu den einzelnen Wohnungen, füllen Sie bitte die nachfolgenden Angaben im Kontaktformular aus:- Name- Anschrift- E-Mail Adresse- Telefon - und /oder Mobilnummer Weniger anzeigen '}
# URL: https://www.immowelt.de/expose/285v85b
# {'url': 'https://www.immowelt.de/expose/285v85b', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Gut instand gehaltene 3-Zimmer-Wohnung nebst 2 Balkone', 'price': '200.000\xa0€', 'living_space': '63', 'rooms': '3', 'badges': 'Zwangsversteigerung;Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Gut', 'equipments': 'Na', 'features': 'Na', 'energy_data': '', 'keywords': ' Geschäftszeiten 08:00 - 20:00 Uhr'}
# URL: https://www.immowelt.de/expose/282v85b
# {'url': 'https://www.immowelt.de/expose/282v85b', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': '3-Zimmer-Wohnung im guten Erhaltungszustand', 'price': '230.000\xa0€', 'living_space': '72', 'rooms': '3', 'badges': 'Zwangsversteigerung;Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Gut', 'equipments': 'Wohnungslage: Erdgeschoss', 'features': 'Na', 'energy_data': '', 'keywords': ' Geschäftszeiten 08:00 - 20:00 Uhr'}
# URL: https://www.immowelt.de/expose/28m5y5a
# {'url': 'https://www.immowelt.de/expose/28m5y5a', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Ideale Kapitalanlage im Herzen Ludwigsburgs', 'price': '250.000\xa0€', 'living_space': '46', 'rooms': '2', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Super', 'rating_public_transport': 'Super', 'equipments': 'Wohnungslage: Erdgeschoss;Bezug: vermietet;Derzeitige Nutzung: vermietet', 'features': 'Balkon;Einbauküche;Böden: Laminat;Weitere Räume: Kelleranteil;Baujahr: 1994;1 Stellplatz: Tiefgarage', 'energy_data': 'Energieträger: Gas;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Wesentliche Energieträger: GAS;Gültigkeit:  18.05.2018 bis 17.05.2028 ;Effizienzklasse: D;Endenergieverbrauch:  113,00 kWh/(m²·a)  - Warmwasser enthalten ;', 'keywords': ' Geschäftszeiten Montag bis Freitag von 9:00 bis 18:00 Uhr'}
# URL: https://www.immowelt.de/expose/28qnu5a
# {'url': 'https://www.immowelt.de/expose/28qnu5a', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Wohnen an den Lucianwiesen', 'price': '323.190\xa0€', 'living_space': '79,80', 'rooms': '2', 'badges': 'Provisionsfrei;Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Okay', 'equipments': 'Kategorie: Penthouse', 'features': 'Böden: Fliesenboden, Teppichboden;Zustand: Erstbezug;Baujahr: 2023;Personenaufzug;44 Stellplätze', 'energy_data': 'Energieträger: Elektro, Gas;Heizungsart: Fußbodenheizung, Luft-/Wasser-Wärmepumpe;', 'keywords': ' Geschäftszeiten Mo - Fr.: 09.30 - 12.00 UhrMo, Die: 14.00 - 16.30 UhrDo:14.00 - 17.30 Uhr'}
# URL: https://www.immowelt.de/expose/28lhm5a
# {'url': 'https://www.immowelt.de/expose/28lhm5a', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': '**Sofort beziehbar: Wohntraum auf 2 Ebenen, 149 m² in Calw-Stammheim**', 'price': '479.500\xa0€', 'living_space': '149', 'rooms': '5', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Okay', 'equipments': 'Wohnungslage: 3. Geschoss;Bezug: sofort', 'features': 'Bad mit Fenster, Wanne und Dusche, Gäste-WC;Balkon;Einbauküche;Böden: Fliesenboden;Zustand: gepflegt;Baujahr: 1990;1 Stellplatz', 'energy_data': 'Energieträger: Gas;Heizungsart: Zentralheizung;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 1990;Wesentliche Energieträger: Gas;Gültigkeit:  27.02.2018 bis 27.02.2028 ;Effizienzklasse: F;Endenergieverbrauch:  188,30 kWh/(m²·a)  ;', 'keywords': ' Geschäftszeiten Bürozeiten: täglich 08.00 Uhr bis 16.00 Uhr'}
# URL: https://www.immowelt.de/expose/28gts59
# {'url': 'https://www.immowelt.de/expose/28gts59', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Gemütliche Stadtwohnung für Individualisten', 'price': '207.000\xa0€', 'living_space': '70,48', 'rooms': '2', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Gut', 'rating_public_transport': 'Okay', 'equipments': 'Kategorie: Maisonette', 'features': 'Baujahr: 1890', 'energy_data': 'Energieausweistyp: Bedarfsausweis;Gebäudetyp: Wohngebäude;Wesentliche Energieträger: GAS;Gültigkeit:  bis 28.07.2030 ;Effizienzklasse: H;Endenergiebedarf:  338,10 kWh/(m²·a)  ;', 'keywords': ' Geschäftszeiten Mo-Do  08:00 - 12:30             14:00 - 17:00Fr         08:00 - 12:30'}
# URL: https://www.immowelt.de/expose/28lmh5b
# {'url': 'https://www.immowelt.de/expose/28lmh5b', 'category': 'wohnungen', 'buy_rent': 'kaufen', 'state': 'bl-baden-wuerttemberg', 'title': 'Wo Ihre Mieter gerne wohnen!', 'price': '176.000\xa0€', 'living_space': '61', 'rooms': '2,5', 'badges': 'Gewerblicher Anbieter', 'rating_location': 'Okay', 'rating_public_transport': 'Mäßig', 'equipments': 'Wohnungslage: Dachgeschoss;Derzeitige Nutzung: vermietet', 'features': 'Garten;Baujahr: 1972;2 Stellplätze', 'energy_data': 'Energieträger: Öl;Heizungsart: Zentralheizung;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 1973;Wesentliche Energieträger: Öl;Gültigkeit:  01.12.2022 bis 01.12.2032 ;Effizienzklasse: D;Endenergieverbrauch:  129,20 kWh/(m²·a)  - Warmwasser enthalten ;', 'keywords': 'Garage vorhanden, Stellplatz vorhanden, Bundesland: Baden-Württemberg'}
# URL: https://www.immowelt.de/expose/28sgh59
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [19], line 8
#       1 immo_scraper = ImmoWeltScraper(
#       2     BASE_URL,
#       3     STATES,
#    (...)
#       6     BUY_CATEGORIES
#       7 )
# ----> 8 immo_scraper.scrape()
#
# Cell In [18], line 22, in ImmoWeltScraper.scrape(self)
#      20 try:
#      21     self._create_driver()
# ---> 22     df = self._scrape()
#      23     self._log("Script successful finished!", "SUCCESS")
#      24 except Exception as exp:
#
# Cell In [18], line 59, in ImmoWeltScraper._scrape(self)
#      55 for expose_url in expose_urls:
#      57     print(f"URL: {expose_url}")
# ---> 59     self.driver.get(expose_url)
#      60     property_data = self._get_property_data(
#      61         property_category,
#      62         buy_category,
#      63         state
#      64     )
#      66     print(property_data)
#
# File ~/opt/miniconda3/envs/tf-env-ds-23/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:455, in WebDriver.get(self, url)
#     451 def get(self, url: str) -> None:
#     452     """
#     453     Loads a web page in the current browser session.
#     454     """
# --> 455     self.execute(Command.GET, {"url": url})
#
# File ~/opt/miniconda3/envs/tf-env-ds-23/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:442, in WebDriver.execute(self, driver_command, params)
#     439     elif "sessionId" not in params:
#     440         params["sessionId"] = self.session_id
# --> 442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
#     444     self.error_handler.check_response(response)
#
# File ~/opt/miniconda3/envs/tf-env-ds-23/lib/python3.9/site-packages/selenium/webdriver/remote/remote_connection.py:294, in RemoteConnection.execute(self, command, params)
#     292 data = utils.dump_json(params)
#     293 url = f"{self._url}{path}"
# --> 294 return self._request(command_info[0], url, body=data)
#
# File ~/opt/miniconda3/envs/tf-env-ds-23/lib/python3.9/site-packages/selenium/webdriver/remote/remote_connection.py:316, in RemoteConnection._request(self, method, url, body)
#     313     body = None
#     315 if self.keep_alive:
# --> 316     response = self._conn.request(method, url, body=body, headers=headers)
#     317     statuscode = response.status
#     318 else:
#
# File ~/opt/miniconda3/envs/tf-env-ds-23/lib/python3.9/site-packages/urllib3/request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File ~/opt/miniconda3/envs/tf-env-ds-23/lib/python3.9/site-packages/urllib3/request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File ~/opt/miniconda3/envs/tf-env-ds-23/lib/python3.9/site-packages/urllib3/poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File ~/opt/miniconda3/envs/tf-env-ds-23/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/opt/miniconda3/envs/tf-env-ds-23/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/opt/miniconda3/envs/tf-env-ds-23/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/opt/miniconda3/envs/tf-env-ds-23/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File ~/opt/miniconda3/envs/tf-env-ds-23/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File ~/opt/miniconda3/envs/tf-env-ds-23/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File ~/opt/miniconda3/envs/tf-env-ds-23/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# KeyboardInterrupt:
