# %% [markdown]
# # WebScraping on ImmoWelt.de

# %% [markdown]
# ## Imports

# %%
import time

import pandas as pd
import bs4

from datetime import datetime

from bs4 import BeautifulSoup
from bs4 import ResultSet
from bs4.element import Tag as HtmlTag
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager

# %% [markdown]
# ## Script

# %%
BUY_CATEGORIES = ["kaufen"]  # ["kaufen", "mieten"]
PROPERTY_CATEGORIES = ["wohnungen", "haeuser"]
HITS_PER_PAGE = 20
BASE_URL = "https://www.immowelt.de/liste/${state}/${property_category}/${buy_category}?d=true&efs=NEW_BUILDING_PROJECT&sd=DESC&sf=RELEVANCE&sp=${page}"

# %%
states = "Baden-Württemberg, Bayern, Berlin, Brandenburg, Bremen, Hamburg, Hessen, Mecklenburg-Vorpommern, Niedersachsen, Nordrhein-Westfalen, Rheinland-Pfalz, Saarland, Sachsen, Sachsen-Anhalt, Schleswig-Holstein, Thüringen"
states = states.replace("ü", "ue").lower().split(", ")
STATES = [f"bl-{state}" for state in states]
STATES
# Out:
# ['bl-baden-wuerttemberg',
#  'bl-bayern',
#  'bl-berlin',
#  'bl-brandenburg',
#  'bl-bremen',
#  'bl-hamburg',
#  'bl-hessen',
#  'bl-mecklenburg-vorpommern',
#  'bl-niedersachsen',
#  'bl-nordrhein-westfalen',
#  'bl-rheinland-pfalz',
#  'bl-saarland',
#  'bl-sachsen',
#  'bl-sachsen-anhalt',
#  'bl-schleswig-holstein',
#  'bl-thueringen']

# %% [markdown]
# ### General Plan
#
# <ol>
#     <li>Get list of Properties</li>
#     <li>Calculate the total Property pages count</li>
#     <li>Get list of Expose URLs of the page</li>
#     <li>Navigate to the Page and grab the Infos you want</li>
#     <li>Loop</li>
# </ol>

# %%
class ImmoWeltScraper:
    def __init__(
        self,
        base_url: str,
        states: list[str],
        hits_per_page: int,
        property_categories: list[str],
        buy_categories: list[str],
    ) -> None:
        self.TIME_DELAY = 5  # 60 * 2.5
        self.driver: webdriver.Chrome = None

        self.base_url = base_url
        self.states = states
        self.hits_per_page = hits_per_page
        self.property_categories = property_categories
        self.buy_categories = buy_categories
    
    def scrape(self) -> pd.DataFrame:
        try:
            self._create_driver()
            df = self._scrape()
            self._log("Script successful finished!", "SUCCESS")
        except Exception as exp:
            self._destroy_driver()
            self._log("Script failed. Try again!", "ERR")
            self._log(str(exp), "ERR_MSG")
            # raise exp
    
    def _scrape(self) -> pd.DataFrame:
        total_loops = len(self.states) * len(self.property_categories) * len(self.buy_categories)
        curr_loop = 0
        total_property_data: list[dict] = []
        for state in self.states:
            state_property_data: list[dict] = []
            for property_category in self.property_categories:
                for buy_category in self.buy_categories:
                    curr_loop += 1
                    self._log(f"Current-Loop: {curr_loop} of {total_loops}")
                    url = self._get_prep_url(state, property_category, buy_category)
                    soup = self._navigate_to(url)
                    if not self._is_page_found(soup):
                        continue
                    
                    page_count = self._calc_total_relevant_page_count(soup)
                    page_count = 35 if page_count > 35 else page_count
                    # page_count = 2 if page_count > 2 else page_count  # just for testing
                    for i in range(0, page_count):
                        try:
                            page = i + 1
                            self._log(f"State: {state}, Category: {property_category}, Type: {buy_category}, Page: {page} of {page_count}")
                            page_url = self._get_prep_url_page(url, page)
                            soup = self._navigate_to(url)

                            expose_urls = self._get_expose_urls(soup)
                            for expose_url in expose_urls:
                                self.driver.get(expose_url)
                                property_data = self._get_property_data(
                                    property_category,
                                    buy_category,
                                    state
                                )
                                state_property_data.append(property_data)
                                total_property_data.append(property_data)
                        except Exception as exp:
                            self._log(f"Err URL: {expose_url}")
                            self._log(str(exp), "WARN")
                            continue
                self._log(f"Category delay of {self.TIME_DELAY}s", "SLEEP")
                time.sleep(self.TIME_DELAY)
            filepath = f"./data2/property_immowelt_{state}.csv"
            _ = self._export(state_property_data, filepath)
            self._log(f"State delay of {self.TIME_DELAY}s", "SLEEP")
            time.sleep(self.TIME_DELAY)
        filepath = "./data2/property_immowelt_data.csv"
        return self._export(total_property_data, filepath)

    def scrape_obj_test(
        self,
        expose_url: str,
    ) -> dict:
        self._create_driver()
        soup = self._navigate_to(expose_url)
        property_data = self._get_property_data(
            soup,
            "property_category",
            "buy_category",
            "state"
        )
        self._destroy_driver()
        return property_data

    def _create_driver(self) -> None:
        if self.driver:
            self._destroy_driver()
        options = Options()
        options.add_argument("--headless")
        self.driver = webdriver.Chrome(
            service=Service(
                ChromeDriverManager().install()
            ),
            options=options
        )
        self._log("Driver created")
        self._check_permission_requirements()
        self._log("Permissions accepted")

    def _destroy_driver(self) -> None:
        self._log("Destroy driver")
        if not self.driver:
            return
        self.driver.close()
        self.driver = None

    def _check_permission_requirements(self, err_loop: int = 0):
        try:
            self.driver.get("https://www.immowelt.de/immobilienpreise")
            check_element = None
            while not check_element:
                check_element = self.driver.execute_script(
                    """return document.querySelector('#usercentrics-root').shadowRoot.querySelector("button[data-testid='uc-accept-all-button']")"""
                )
                if check_element:
                    check_element.click()
                else:
                    self._log("Permission loop. Wait 2 seconds.")
                    time.sleep(2)
        except Exception as exp:
            err_loop += 1
            if err_loop == 5:
                raise exp
            self._log(f"Permission ERR#{err_loop}-loop", "WARN")
            self._check_permission_requirements(err_loop)

    def _export(self, data: list[dict], filepath: str) -> pd.DataFrame:
        df = pd.DataFrame(data)
        df.replace("|", "_", inplace=True)
        df.to_csv(filepath, sep="|", index=False)
        self._log(f"CSV-Export to: {filepath}")
        return df

    def _navigate_to(self, url: str) -> BeautifulSoup:
        self.driver.get(url)
        return BeautifulSoup(self.driver.page_source)

    def _is_page_found(self, soup: BeautifulSoup) -> bool:
        is_page_found = not soup.find("div", {"class": "NotFound-d39a0"})
        if not is_page_found:
            url = self.driver.current_url
            self._log(f"Page not Found: {url}", "ERROR")
        return is_page_found

    def _log(self, msg: str, tag: str = "INFO") -> None:
        tag = tag.upper()
        ts = datetime.now().strftime("%Y-%m-%d, %H:%M:%S")
        print(f"[{ts}] {tag}:\t{msg}")

    def _get_prep_url(
        self,
        state: str,
        property_category: str,
        buy_category: str,
        page: int = 1
    ) -> str:
        page = str(page)
        return (
            self.base_url
                .replace("${state}", state)
                .replace("${property_category}", property_category)
                .replace("${buy_category}", buy_category)
                .replace("${page}", page)
        )

    def _get_prep_url_page(self, url: str, page: int) -> str:
        url_page_removed = url[:url.find("sp=")]
        return f"{url_page_removed}sp={page}"

    def _calc_total_relevant_page_count(self, soup: BeautifulSoup) -> int:
        hits_emt = soup.find("h1", {"class": "MatchNumber-a225f"})
        if not hits_emt:
            return 0
        content = hits_emt.text
        hits = content[:content.find(" ")].replace(".", "")
        page_count = int(int(hits) / self.hits_per_page)
        return page_count

    def _get_expose_urls(self, soup: BeautifulSoup) -> list[str]:
        expose_urls_emt = soup.find_all("a", {"class": "mainSection-b22fb"})
        expose_urls = [link["href"] for link in expose_urls_emt]
        return expose_urls

    def _expand_read_more_areas(self, err_loop = 0) -> BeautifulSoup:
        try:
            script_expand_all_read_more = """
            let links = document.getElementsByClassName("link--read-more");
            while(links.length > 0) {
                links[0].click(); 
                links = document.getElementsByClassName("link--read-more");
            }
            """
            self.driver.execute_script(script_expand_all_read_more)
            return BeautifulSoup(self.driver.page_source)
        except Exception as exp:
            print("EXEPTION!!")
            if err_loop >= 5:
                raise exp
            err_loop += + 1
            self._log(f"Can't expand read-more. Try: {err_loop} of 5", "WARN")
            self._expand_read_more_areas(err_loop)

    def _get_overview_container(self, soup: BeautifulSoup) -> HtmlTag:
        return soup.find("app-objectmeta", {"id": "aUebersicht"})
    
    def _get_data_title(self, overview_container: HtmlTag) -> str:
        emt = overview_container.find("h1", {"class": "ng-star-inserted"})
        return emt.text if emt else "Na"
    
    def _get_data_hardfacts(self, overview_container: HtmlTag) -> tuple[str, str, str]:
        hardfact_emts = overview_container.find_all("div", {"class": "hardfact ng-star-inserted"})

        def prep_text(emt):
            content: str = emt.text.strip()
            return content[:content.find(" ")]

        hardfact_emt: HtmlTag
        price = "Na"
        living_space = "Na"
        rooms = "Na"
        for hardfact_emt in hardfact_emts:
            hardfact_label = hardfact_emt.find("div", {"class": "hardfact__label"}).text.strip()
            value = prep_text(hardfact_emt)
            if hardfact_label == "Kaufpreis" or hardfact_label == "Mindestpreis":
                price = value
            elif hardfact_label == "Wohnfläche ca.":
                living_space = value
            elif hardfact_label == "Zimmer":
                rooms = value
        
        if price == "Na":
            emt: HtmlTag = overview_container.find("div", {"class": "hardfact hardfact__price ng-star-inserted"})
            price = emt.findChild().text.strip() if emt and emt.findChild() else "Na"
        
        return price, living_space, rooms
    
    def _get_data_badges(self, overview_container: BeautifulSoup) -> str:
        badge_emts = overview_container.find_all("sd-badge")
        badges = "Na"
        if badge_emts:
            badges = ";".join([legal_info.text for legal_info in badge_emts])
        return badges

    def _get_data_ratings(self, soup: BeautifulSoup) -> tuple[str, str]:
        rating_emts = soup.find_all("div", {"class": "rating-meter__value"})
        location_rating = "Na"
        public_transport_rating = "Na"
        if len(rating_emts) == 2:
            location_rating = rating_emts[0].text
            public_transport_rating = rating_emts[1].text
        return location_rating, public_transport_rating

    def _get_data_equipments(self, soup: BeautifulSoup) -> str:
        equipment_container = soup.find("div", {"class": "equipment card-content ng-star-inserted"})
        if not equipment_container:
            return "Na"

        equipment_cells = equipment_container.find_all("sd-cell-row", {"class": "cell__row"})
        if not equipment_cells:
            return "Na"

        equipments = ""
        equipment_cell: HtmlTag
        for equipment_cell in equipment_cells:
            values = equipment_cell.find_all("p")
            if len(values) >= 2:
                title = values[0].text
                value = values[1].text
                equipments += f"{title}: {value};"

        return equipments[:len(equipments)-1] if equipments else "Na"
    
    def _get_data_features(self, soup: BeautifulSoup) -> str:
        feature_list_emts = soup.find_all("div", {"class": "textlist"})
        if not feature_list_emts:
            return "Na"
        features = ""
        feature_list_emt: HtmlTag
        for feature_list_emt in feature_list_emts:
            feature_emts = feature_list_emt.find_all("li")
            if feature_emts:
                feature_emt: HtmlTag
                for feature_emt in feature_emts:
                    features += f"{feature_emt.text.strip()};"

        return features[:len(features)-1]

    def _get_data_energy_data(self, soup: BeautifulSoup) -> str:
        energy_data = ""

        def get_data(curr_energy_data: str, energy_cells: ResultSet) -> str:
            if not energy_cells:
                return curr_energy_data

            energy_cell: HtmlTag
            for energy_cell in energy_cells:
                content_emts = energy_cell.find_all("p")
                title = content_emts[0].text
                content = content_emts[1].text
                curr_energy_data += f"{title}: {content};"

            return curr_energy_data

        energy_container1 = soup.find("app-energy-equipment")
        if energy_container1:
            energy_cells = energy_container1.find_all("sd-cell-col", {"data-cy": "energy-equipment"})
            energy_data = get_data(energy_data, energy_cells)

        energy_container2 = soup.find("div", {"class": "energy_information ng-star-inserted"})
        if energy_container2:
            energy_cells = energy_container2.find_all("sd-cell-col", {"class": "cell__col"})
            energy_data = get_data(energy_data, energy_cells)

        return energy_data[:len(energy_data)]

    def _get_data_keywords(self, soup: BeautifulSoup) -> str:
        read_more_emts = soup.find_all("sd-read-more")
        keywords = "Na"
        if not read_more_emts:
            return keywords.strip()

        last_emt_idx = len(read_more_emts) - 1
        keywords: str = read_more_emts[last_emt_idx].text
        KEYWORDS_NAME = "Stichworte"
        if not KEYWORDS_NAME in keywords:
            return keywords
        start_idx = keywords.find(KEYWORDS_NAME) + len(KEYWORDS_NAME)
        keywords = keywords[start_idx:]
        return keywords.strip()

    def _get_property_data(
        self,
        category: str,
        buy_rent: str,
        state: str,
    ) -> dict:
        soup = self._expand_read_more_areas()
        overview_container = self._get_overview_container(soup)

        url = self.driver.current_url
        title = self._get_data_title(overview_container)
        price, living_space, rooms = self._get_data_hardfacts(overview_container)
        badges = self._get_data_badges(overview_container)
        rating_location, rating_public_transport = self._get_data_ratings(soup)
        equipments = self._get_data_equipments(soup)
        features = self._get_data_features(soup)
        energy_data = self._get_data_energy_data(soup)
        keywords = self._get_data_keywords(soup)

        return {
            # "url": url,
            "category": category,
            "buy_rent": buy_rent,
            "state": state,
            "title": title,
            "price": price,
            "living_space": living_space,
            "rooms": rooms,
            "badges": badges,
            "rating_location": rating_location,
            "rating_public_transport": rating_public_transport,
            "equipments": equipments,
            "features": features,
            "energy_data": energy_data,
            "keywords": keywords,
            # image_paths: str,
        }

# %% [markdown]
# ## Run Script

# %%
immo_scraper = ImmoWeltScraper(
    BASE_URL,
    STATES,
    HITS_PER_PAGE,
    PROPERTY_CATEGORIES,
    BUY_CATEGORIES
)
immo_scraper.scrape()
# Out:
# [2022-12-24, 11:15:45] INFO:	Driver created
# [2022-12-24, 11:15:46] INFO:	Permission loop. Wait 2 seconds.
# [2022-12-24, 11:15:48] INFO:	Permissions accepted
# [2022-12-24, 11:15:48] INFO:	Current-Loop: 1 of 32
# [2022-12-24, 11:15:53] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 1 of 35
# [2022-12-24, 11:17:05] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 2 of 35
# [2022-12-24, 11:18:16] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 3 of 35
# [2022-12-24, 11:19:26] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 4 of 35
# [2022-12-24, 11:20:37] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 5 of 35
# [2022-12-24, 11:21:47] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 6 of 35
# [2022-12-24, 11:22:58] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 7 of 35
# [2022-12-24, 11:24:08] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 8 of 35
# [2022-12-24, 11:25:20] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 9 of 35
# [2022-12-24, 11:26:31] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 10 of 35
# [2022-12-24, 11:27:42] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 11 of 35
# [2022-12-24, 11:28:52] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 12 of 35
# [2022-12-24, 11:30:02] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 13 of 35
# [2022-12-24, 11:31:12] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 14 of 35
# [2022-12-24, 11:32:22] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 15 of 35
# [2022-12-24, 11:33:32] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 16 of 35
# [2022-12-24, 11:34:42] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 17 of 35
# [2022-12-24, 11:35:54] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 18 of 35
# [2022-12-24, 11:37:04] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 19 of 35
# [2022-12-24, 11:38:15] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 20 of 35
# [2022-12-24, 11:39:25] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 21 of 35
# [2022-12-24, 11:40:35] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 22 of 35
# [2022-12-24, 11:41:45] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 23 of 35
# [2022-12-24, 11:42:55] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 24 of 35
# [2022-12-24, 11:44:06] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 25 of 35
# [2022-12-24, 11:45:17] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 26 of 35
# [2022-12-24, 11:46:27] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 27 of 35
# [2022-12-24, 11:47:37] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 28 of 35
# [2022-12-24, 11:48:48] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 29 of 35
# [2022-12-24, 11:49:58] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 30 of 35
# [2022-12-24, 11:51:09] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 31 of 35
# [2022-12-24, 11:52:20] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 32 of 35
# [2022-12-24, 11:53:32] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 33 of 35
# [2022-12-24, 11:54:43] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 34 of 35
# [2022-12-24, 11:55:53] INFO:	State: bl-baden-wuerttemberg, Category: wohnungen, Type: kaufen, Page: 35 of 35
# [2022-12-24, 11:57:04] SLEEP:	Category delay of 5s
# [2022-12-24, 11:57:09] INFO:	Current-Loop: 2 of 32
# [2022-12-24, 11:57:10] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 1 of 35
# [2022-12-24, 11:58:22] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 2 of 35
# [2022-12-24, 11:59:35] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 3 of 35
# [2022-12-24, 12:00:47] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 4 of 35
# [2022-12-24, 12:01:59] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 5 of 35
# [2022-12-24, 12:03:10] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 6 of 35
# [2022-12-24, 12:04:23] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 7 of 35
# [2022-12-24, 12:05:34] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 8 of 35
# [2022-12-24, 12:06:45] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 9 of 35
# [2022-12-24, 12:07:56] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 10 of 35
# [2022-12-24, 12:09:09] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 11 of 35
# [2022-12-24, 12:10:20] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 12 of 35
# [2022-12-24, 12:11:32] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 13 of 35
# [2022-12-24, 12:12:43] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 14 of 35
# [2022-12-24, 12:13:54] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 15 of 35
# [2022-12-24, 12:15:06] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 16 of 35
# [2022-12-24, 12:16:18] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 17 of 35
# [2022-12-24, 12:17:28] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 18 of 35
# [2022-12-24, 12:18:40] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 19 of 35
# [2022-12-24, 12:19:51] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 20 of 35
# [2022-12-24, 12:21:02] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 21 of 35
# [2022-12-24, 12:22:14] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 22 of 35
# [2022-12-24, 12:23:26] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 23 of 35
# [2022-12-24, 12:24:37] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 24 of 35
# [2022-12-24, 12:25:48] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 25 of 35
# [2022-12-24, 12:26:59] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 26 of 35
# [2022-12-24, 12:28:11] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 27 of 35
# [2022-12-24, 12:29:22] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 28 of 35
# [2022-12-24, 12:30:34] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 29 of 35
# [2022-12-24, 12:31:46] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 30 of 35
# [2022-12-24, 12:32:57] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 31 of 35
# [2022-12-24, 12:34:09] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 32 of 35
# [2022-12-24, 12:35:20] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 33 of 35
# [2022-12-24, 12:36:32] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 34 of 35
# [2022-12-24, 12:37:44] INFO:	State: bl-baden-wuerttemberg, Category: haeuser, Type: kaufen, Page: 35 of 35
# [2022-12-24, 12:38:56] SLEEP:	Category delay of 5s
# [2022-12-24, 12:39:01] INFO:	CSV-Export to: ./data2/property_immowelt_bl-baden-wuerttemberg.csv
# [2022-12-24, 12:39:01] SLEEP:	State delay of 5s
# [2022-12-24, 12:39:06] INFO:	Current-Loop: 3 of 32
# [2022-12-24, 12:39:07] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 1 of 35
# [2022-12-24, 12:40:19] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 2 of 35
# [2022-12-24, 12:41:31] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 3 of 35
# [2022-12-24, 12:42:44] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 4 of 35
# [2022-12-24, 12:43:58] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 5 of 35
# [2022-12-24, 12:45:10] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 6 of 35
# [2022-12-24, 12:46:23] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 7 of 35
# [2022-12-24, 12:47:34] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 8 of 35
# [2022-12-24, 12:48:46] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 9 of 35
# [2022-12-24, 12:49:58] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 10 of 35
# [2022-12-24, 12:51:10] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 11 of 35
# [2022-12-24, 12:52:22] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 12 of 35
# [2022-12-24, 12:53:34] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 13 of 35
# [2022-12-24, 12:54:46] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 14 of 35
# [2022-12-24, 12:55:59] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 15 of 35
# [2022-12-24, 12:57:11] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 16 of 35
# [2022-12-24, 12:58:23] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 17 of 35
# [2022-12-24, 12:59:36] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 18 of 35
# [2022-12-24, 13:00:48] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 19 of 35
# [2022-12-24, 13:02:01] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 20 of 35
# [2022-12-24, 13:03:14] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 21 of 35
# [2022-12-24, 13:04:27] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 22 of 35
# [2022-12-24, 13:05:39] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 23 of 35
# [2022-12-24, 13:06:50] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 24 of 35
# [2022-12-24, 13:08:02] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 25 of 35
# [2022-12-24, 13:09:14] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 26 of 35
# [2022-12-24, 13:10:26] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 27 of 35
# [2022-12-24, 13:11:37] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 28 of 35
# [2022-12-24, 13:12:49] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 29 of 35
# [2022-12-24, 13:14:01] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 30 of 35
# [2022-12-24, 13:15:14] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 31 of 35
# [2022-12-24, 13:16:25] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 32 of 35
# [2022-12-24, 13:17:37] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 33 of 35
# [2022-12-24, 13:18:50] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 34 of 35
# [2022-12-24, 13:20:03] INFO:	State: bl-bayern, Category: wohnungen, Type: kaufen, Page: 35 of 35
# [2022-12-24, 13:21:15] SLEEP:	Category delay of 5s
# [2022-12-24, 13:21:20] INFO:	Current-Loop: 4 of 32
# [2022-12-24, 13:21:24] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 1 of 35
# [2022-12-24, 13:22:40] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 2 of 35
# [2022-12-24, 13:23:51] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 3 of 35
# [2022-12-24, 13:25:04] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 4 of 35
# [2022-12-24, 13:26:17] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 5 of 35
# [2022-12-24, 13:27:29] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 6 of 35
# [2022-12-24, 13:28:42] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 7 of 35
# [2022-12-24, 13:29:54] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 8 of 35
# [2022-12-24, 13:31:07] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 9 of 35
# [2022-12-24, 13:32:21] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 10 of 35
# [2022-12-24, 13:33:33] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 11 of 35
# [2022-12-24, 13:34:46] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 12 of 35
# [2022-12-24, 13:35:57] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 13 of 35
# [2022-12-24, 13:37:10] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 14 of 35
# [2022-12-24, 13:38:23] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 15 of 35
# [2022-12-24, 13:39:35] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 16 of 35
# [2022-12-24, 13:40:48] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 17 of 35
# [2022-12-24, 13:42:01] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 18 of 35
# [2022-12-24, 13:43:13] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 19 of 35
# [2022-12-24, 13:44:26] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 20 of 35
# [2022-12-24, 13:45:40] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 21 of 35
# [2022-12-24, 13:46:53] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 22 of 35
# [2022-12-24, 13:48:06] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 23 of 35
# [2022-12-24, 13:49:19] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 24 of 35
# [2022-12-24, 13:50:32] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 25 of 35
# [2022-12-24, 13:51:45] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 26 of 35
# [2022-12-24, 13:52:59] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 27 of 35
# [2022-12-24, 13:54:13] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 28 of 35
# [2022-12-24, 13:55:26] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 29 of 35
# [2022-12-24, 13:56:39] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 30 of 35
# [2022-12-24, 13:57:52] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 31 of 35
# [2022-12-24, 13:59:05] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 32 of 35
# [2022-12-24, 14:00:19] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 33 of 35
# [2022-12-24, 14:01:32] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 34 of 35
# [2022-12-24, 14:02:46] INFO:	State: bl-bayern, Category: haeuser, Type: kaufen, Page: 35 of 35
# [2022-12-24, 14:04:01] SLEEP:	Category delay of 5s
# [2022-12-24, 14:04:06] INFO:	CSV-Export to: ./data2/property_immowelt_bl-bayern.csv
# [2022-12-24, 14:04:06] SLEEP:	State delay of 5s
# [2022-12-24, 14:04:11] INFO:	Current-Loop: 5 of 32
# [2022-12-24, 14:04:12] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 1 of 35
# [2022-12-24, 14:05:26] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 2 of 35
# [2022-12-24, 14:06:41] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 3 of 35
# [2022-12-24, 14:07:55] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 4 of 35
# [2022-12-24, 14:09:09] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 5 of 35
# [2022-12-24, 14:10:24] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 6 of 35
# [2022-12-24, 14:11:39] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 7 of 35
# [2022-12-24, 14:12:54] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 8 of 35
# [2022-12-24, 14:14:10] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 9 of 35
# [2022-12-24, 14:15:27] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 10 of 35
# [2022-12-24, 14:16:43] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 11 of 35
# [2022-12-24, 14:17:59] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 12 of 35
# [2022-12-24, 14:19:15] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 13 of 35
# [2022-12-24, 14:20:31] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 14 of 35
# [2022-12-24, 14:21:48] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 15 of 35
# [2022-12-24, 14:23:04] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 16 of 35
# [2022-12-24, 14:24:20] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 17 of 35
# [2022-12-24, 14:25:35] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 18 of 35
# [2022-12-24, 14:26:50] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 19 of 35
# [2022-12-24, 14:28:05] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 20 of 35
# [2022-12-24, 14:29:20] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 21 of 35
# [2022-12-24, 14:30:35] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 22 of 35
# [2022-12-24, 14:31:50] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 23 of 35
# [2022-12-24, 14:33:05] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 24 of 35
# [2022-12-24, 14:34:20] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 25 of 35
# [2022-12-24, 14:35:35] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 26 of 35
# [2022-12-24, 14:36:50] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 27 of 35
# [2022-12-24, 14:38:05] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 28 of 35
# [2022-12-24, 14:39:21] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 29 of 35
# [2022-12-24, 14:40:37] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 30 of 35
# [2022-12-24, 14:41:52] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 31 of 35
# [2022-12-24, 14:43:08] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 32 of 35
# [2022-12-24, 14:44:24] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 33 of 35
# [2022-12-24, 14:45:40] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 34 of 35
# [2022-12-24, 14:46:56] INFO:	State: bl-berlin, Category: wohnungen, Type: kaufen, Page: 35 of 35
# [2022-12-24, 14:48:11] SLEEP:	Category delay of 5s
# [2022-12-24, 14:48:16] INFO:	Current-Loop: 6 of 32
# [2022-12-24, 14:48:18] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 1 of 35
# [2022-12-24, 14:49:34] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 2 of 35
# [2022-12-24, 14:50:49] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 3 of 35
# [2022-12-24, 14:52:05] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 4 of 35
# [2022-12-24, 14:53:22] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 5 of 35
# [2022-12-24, 14:54:38] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 6 of 35
# [2022-12-24, 14:55:54] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 7 of 35
# [2022-12-24, 14:57:11] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 8 of 35
# [2022-12-24, 14:58:27] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 9 of 35
# [2022-12-24, 14:59:45] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 10 of 35
# [2022-12-24, 15:01:00] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 11 of 35
# [2022-12-24, 15:02:16] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 12 of 35
# [2022-12-24, 15:03:33] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 13 of 35
# [2022-12-24, 15:04:50] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 14 of 35
# [2022-12-24, 15:06:07] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 15 of 35
# [2022-12-24, 15:07:23] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 16 of 35
# [2022-12-24, 15:08:40] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 17 of 35
# [2022-12-24, 15:09:57] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 18 of 35
# [2022-12-24, 15:11:14] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 19 of 35
# [2022-12-24, 15:12:31] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 20 of 35
# [2022-12-24, 15:13:47] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 21 of 35
# [2022-12-24, 15:15:04] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 22 of 35
# [2022-12-24, 15:16:21] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 23 of 35
# [2022-12-24, 15:17:38] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 24 of 35
# [2022-12-24, 15:18:54] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 25 of 35
# [2022-12-24, 15:20:12] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 26 of 35
# [2022-12-24, 15:21:28] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 27 of 35
# [2022-12-24, 15:22:45] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 28 of 35
# [2022-12-24, 15:24:02] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 29 of 35
# [2022-12-24, 15:25:19] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 30 of 35
# [2022-12-24, 15:26:36] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 31 of 35
# [2022-12-24, 15:27:53] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 32 of 35
# [2022-12-24, 15:29:11] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 33 of 35
# [2022-12-24, 15:30:28] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 34 of 35
# [2022-12-24, 15:31:45] INFO:	State: bl-berlin, Category: haeuser, Type: kaufen, Page: 35 of 35
# [2022-12-24, 15:33:03] SLEEP:	Category delay of 5s
# [2022-12-24, 15:33:08] INFO:	CSV-Export to: ./data2/property_immowelt_bl-berlin.csv
# [2022-12-24, 15:33:08] SLEEP:	State delay of 5s
# [2022-12-24, 15:33:13] INFO:	Current-Loop: 7 of 32
# [2022-12-24, 15:33:15] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 1 of 35
# [2022-12-24, 15:34:35] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 2 of 35
# [2022-12-24, 15:35:53] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 3 of 35
# [2022-12-24, 15:37:10] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 4 of 35
# [2022-12-24, 15:38:28] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 5 of 35
# [2022-12-24, 15:39:47] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 6 of 35
# [2022-12-24, 15:41:05] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 7 of 35
# [2022-12-24, 15:42:23] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 8 of 35
# [2022-12-24, 15:43:41] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 9 of 35
# [2022-12-24, 15:45:00] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 10 of 35
# [2022-12-24, 15:46:19] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 11 of 35
# [2022-12-24, 15:47:40] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 12 of 35
# [2022-12-24, 15:48:58] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 13 of 35
# [2022-12-24, 15:50:17] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 14 of 35
# [2022-12-24, 15:51:37] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 15 of 35
# [2022-12-24, 15:52:56] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 16 of 35
# [2022-12-24, 15:54:14] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 17 of 35
# [2022-12-24, 15:55:33] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 18 of 35
# [2022-12-24, 15:56:51] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 19 of 35
# [2022-12-24, 15:58:10] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 20 of 35
# [2022-12-24, 15:59:29] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 21 of 35
# [2022-12-24, 16:00:48] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 22 of 35
# [2022-12-24, 16:02:09] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 23 of 35
# [2022-12-24, 16:03:28] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 24 of 35
# [2022-12-24, 16:04:46] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 25 of 35
# [2022-12-24, 16:06:04] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 26 of 35
# [2022-12-24, 16:07:23] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 27 of 35
# [2022-12-24, 16:08:42] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 28 of 35
# [2022-12-24, 16:10:02] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 29 of 35
# [2022-12-24, 16:11:21] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 30 of 35
# [2022-12-24, 16:12:40] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 31 of 35
# [2022-12-24, 16:13:58] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 32 of 35
# [2022-12-24, 16:15:17] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 33 of 35
# [2022-12-24, 16:16:37] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 34 of 35
# [2022-12-24, 16:17:56] INFO:	State: bl-brandenburg, Category: wohnungen, Type: kaufen, Page: 35 of 35
# [2022-12-24, 16:19:15] SLEEP:	Category delay of 5s
# [2022-12-24, 16:19:20] INFO:	Current-Loop: 8 of 32
# [2022-12-24, 16:19:22] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 1 of 35
# [2022-12-24, 16:20:41] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 2 of 35
# [2022-12-24, 16:22:00] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 3 of 35
# [2022-12-24, 16:23:19] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 4 of 35
# [2022-12-24, 16:24:39] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 5 of 35
# [2022-12-24, 16:25:58] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 6 of 35
# [2022-12-24, 16:27:17] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 7 of 35
# [2022-12-24, 16:28:36] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 8 of 35
# [2022-12-24, 16:29:55] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 9 of 35
# [2022-12-24, 16:31:14] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 10 of 35
# [2022-12-24, 16:32:33] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 11 of 35
# [2022-12-24, 16:33:52] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 12 of 35
# [2022-12-24, 16:35:12] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 13 of 35
# [2022-12-24, 16:36:30] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 14 of 35
# [2022-12-24, 16:37:49] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 15 of 35
# [2022-12-24, 16:39:09] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 16 of 35
# [2022-12-24, 16:40:28] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 17 of 35
# [2022-12-24, 16:41:47] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 18 of 35
# [2022-12-24, 16:43:07] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 19 of 35
# [2022-12-24, 16:44:25] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 20 of 35
# [2022-12-24, 16:45:44] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 21 of 35
# [2022-12-24, 16:47:04] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 22 of 35
# [2022-12-24, 16:48:23] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 23 of 35
# [2022-12-24, 16:49:42] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 24 of 35
# [2022-12-24, 16:51:00] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 25 of 35
# [2022-12-24, 16:52:20] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 26 of 35
# [2022-12-24, 16:53:39] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 27 of 35
# [2022-12-24, 16:54:57] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 28 of 35
# [2022-12-24, 16:56:17] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 29 of 35
# [2022-12-24, 16:57:36] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 30 of 35
# [2022-12-24, 16:58:56] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 31 of 35
# [2022-12-24, 17:00:17] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 32 of 35
# [2022-12-24, 17:01:37] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 33 of 35
# [2022-12-24, 17:02:56] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 34 of 35
# [2022-12-24, 17:04:15] INFO:	State: bl-brandenburg, Category: haeuser, Type: kaufen, Page: 35 of 35
# [2022-12-24, 17:05:34] SLEEP:	Category delay of 5s
# [2022-12-24, 17:05:39] INFO:	CSV-Export to: ./data2/property_immowelt_bl-brandenburg.csv
# [2022-12-24, 17:05:39] SLEEP:	State delay of 5s
# [2022-12-24, 17:05:44] INFO:	Current-Loop: 9 of 32
# [2022-12-24, 17:05:46] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 1 of 27
# [2022-12-24, 17:07:07] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 2 of 27
# [2022-12-24, 17:08:28] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 3 of 27
# [2022-12-24, 17:09:50] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 4 of 27
# [2022-12-24, 17:11:11] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 5 of 27
# [2022-12-24, 17:12:33] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 6 of 27
# [2022-12-24, 17:13:54] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 7 of 27
# [2022-12-24, 17:15:16] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 8 of 27
# [2022-12-24, 17:16:39] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 9 of 27
# [2022-12-24, 17:18:03] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 10 of 27
# [2022-12-24, 17:19:25] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 11 of 27
# [2022-12-24, 17:20:48] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 12 of 27
# [2022-12-24, 17:22:10] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 13 of 27
# [2022-12-24, 17:23:33] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 14 of 27
# [2022-12-24, 17:24:56] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 15 of 27
# [2022-12-24, 17:26:18] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 16 of 27
# [2022-12-24, 17:27:41] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 17 of 27
# [2022-12-24, 17:29:05] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 18 of 27
# [2022-12-24, 17:30:28] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 19 of 27
# [2022-12-24, 17:31:51] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 20 of 27
# [2022-12-24, 17:33:14] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 21 of 27
# [2022-12-24, 17:34:38] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 22 of 27
# [2022-12-24, 17:36:02] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 23 of 27
# [2022-12-24, 17:37:25] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 24 of 27
# [2022-12-24, 17:38:49] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 25 of 27
# [2022-12-24, 17:40:15] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 26 of 27
# [2022-12-24, 17:41:39] INFO:	State: bl-bremen, Category: wohnungen, Type: kaufen, Page: 27 of 27
# [2022-12-24, 17:43:04] SLEEP:	Category delay of 5s
# [2022-12-24, 17:43:09] INFO:	Current-Loop: 10 of 32
# [2022-12-24, 17:43:10] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 1 of 33
# [2022-12-24, 17:44:36] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 2 of 33
# [2022-12-24, 17:46:00] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 3 of 33
# [2022-12-24, 17:47:26] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 4 of 33
# [2022-12-24, 17:48:52] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 5 of 33
# [2022-12-24, 17:50:18] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 6 of 33
# [2022-12-24, 17:51:44] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 7 of 33
# [2022-12-24, 17:53:11] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 8 of 33
# [2022-12-24, 17:54:37] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 9 of 33
# [2022-12-24, 17:56:04] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 10 of 33
# [2022-12-24, 17:57:31] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 11 of 33
# [2022-12-24, 17:58:57] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 12 of 33
# [2022-12-24, 18:00:23] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 13 of 33
# [2022-12-24, 18:01:51] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 14 of 33
# [2022-12-24, 18:03:16] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 15 of 33
# [2022-12-24, 18:04:43] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 16 of 33
# [2022-12-24, 18:06:09] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 17 of 33
# [2022-12-24, 18:07:38] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 18 of 33
# [2022-12-24, 18:09:05] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 19 of 33
# [2022-12-24, 18:10:32] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 20 of 33
# [2022-12-24, 18:11:59] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 21 of 33
# [2022-12-24, 18:13:27] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 22 of 33
# [2022-12-24, 18:14:53] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 23 of 33
# [2022-12-24, 18:16:22] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 24 of 33
# [2022-12-24, 18:17:49] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 25 of 33
# [2022-12-24, 18:19:16] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 26 of 33
# [2022-12-24, 18:20:43] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 27 of 33
# [2022-12-24, 18:22:09] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 28 of 33
# [2022-12-24, 18:23:37] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 29 of 33
# [2022-12-24, 18:25:05] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 30 of 33
# [2022-12-24, 18:26:32] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 31 of 33
# [2022-12-24, 18:27:59] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 32 of 33
# [2022-12-24, 18:29:26] INFO:	State: bl-bremen, Category: haeuser, Type: kaufen, Page: 33 of 33
# [2022-12-24, 18:30:54] SLEEP:	Category delay of 5s
# [2022-12-24, 18:30:59] INFO:	CSV-Export to: ./data2/property_immowelt_bl-bremen.csv
# [2022-12-24, 18:30:59] SLEEP:	State delay of 5s
# [2022-12-24, 18:31:04] INFO:	Current-Loop: 11 of 32
# [2022-12-24, 18:31:06] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 1 of 35
# [2022-12-24, 18:32:33] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 2 of 35
# [2022-12-24, 18:34:00] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 3 of 35
# [2022-12-24, 18:35:27] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 4 of 35
# [2022-12-24, 18:36:54] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 5 of 35
# [2022-12-24, 18:38:21] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 6 of 35
# [2022-12-24, 18:39:48] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 7 of 35
# [2022-12-24, 18:41:15] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 8 of 35
# [2022-12-24, 18:42:42] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 9 of 35
# [2022-12-24, 18:44:09] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 10 of 35
# [2022-12-24, 18:45:35] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 11 of 35
# [2022-12-24, 18:47:03] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 12 of 35
# [2022-12-24, 18:48:30] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 13 of 35
# [2022-12-24, 18:49:57] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 14 of 35
# [2022-12-24, 18:51:25] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 15 of 35
# [2022-12-24, 18:52:52] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 16 of 35
# [2022-12-24, 18:54:20] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 17 of 35
# [2022-12-24, 18:55:47] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 18 of 35
# [2022-12-24, 18:57:15] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 19 of 35
# [2022-12-24, 18:58:42] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 20 of 35
# [2022-12-24, 19:00:10] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 21 of 35
# [2022-12-24, 19:01:38] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 22 of 35
# [2022-12-24, 19:03:05] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 23 of 35
# [2022-12-24, 19:04:33] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 24 of 35
# [2022-12-24, 19:06:01] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 25 of 35
# [2022-12-24, 19:07:27] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 26 of 35
# [2022-12-24, 19:08:55] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 27 of 35
# [2022-12-24, 19:10:22] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 28 of 35
# [2022-12-24, 19:11:50] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 29 of 35
# [2022-12-24, 19:13:19] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 30 of 35
# [2022-12-24, 19:14:46] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 31 of 35
# [2022-12-24, 19:16:15] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 32 of 35
# [2022-12-24, 19:17:43] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 33 of 35
# [2022-12-24, 19:19:12] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 34 of 35
# [2022-12-24, 19:20:39] INFO:	State: bl-hamburg, Category: wohnungen, Type: kaufen, Page: 35 of 35
# [2022-12-24, 19:22:08] SLEEP:	Category delay of 5s
# [2022-12-24, 19:22:13] INFO:	Current-Loop: 12 of 32
# [2022-12-24, 19:22:15] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 1 of 35
# [2022-12-24, 19:23:45] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 2 of 35
# [2022-12-24, 19:25:15] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 3 of 35
# [2022-12-24, 19:26:45] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 4 of 35
# [2022-12-24, 19:28:15] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 5 of 35
# [2022-12-24, 19:29:44] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 6 of 35
# [2022-12-24, 19:31:14] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 7 of 35
# [2022-12-24, 19:32:44] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 8 of 35
# [2022-12-24, 19:34:12] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 9 of 35
# [2022-12-24, 19:35:42] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 10 of 35
# [2022-12-24, 19:37:13] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 11 of 35
# [2022-12-24, 19:38:44] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 12 of 35
# [2022-12-24, 19:40:14] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 13 of 35
# [2022-12-24, 19:41:45] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 14 of 35
# [2022-12-24, 19:43:18] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 15 of 35
# [2022-12-24, 19:44:51] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 16 of 35
# [2022-12-24, 19:46:23] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 17 of 35
# [2022-12-24, 19:47:55] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 18 of 35
# [2022-12-24, 19:49:27] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 19 of 35
# [2022-12-24, 19:50:58] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 20 of 35
# [2022-12-24, 19:52:27] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 21 of 35
# [2022-12-24, 19:53:57] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 22 of 35
# [2022-12-24, 19:55:28] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 23 of 35
# [2022-12-24, 19:56:57] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 24 of 35
# [2022-12-24, 19:58:27] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 25 of 35
# [2022-12-24, 19:59:56] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 26 of 35
# [2022-12-24, 20:01:28] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 27 of 35
# [2022-12-24, 20:02:58] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 28 of 35
# [2022-12-24, 20:04:29] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 29 of 35
# [2022-12-24, 20:05:59] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 30 of 35
# [2022-12-24, 20:07:29] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 31 of 35
# [2022-12-24, 20:08:59] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 32 of 35
# [2022-12-24, 20:10:29] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 33 of 35
# [2022-12-24, 20:12:00] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 34 of 35
# [2022-12-24, 20:13:31] INFO:	State: bl-hamburg, Category: haeuser, Type: kaufen, Page: 35 of 35
# [2022-12-24, 20:15:02] SLEEP:	Category delay of 5s
# [2022-12-24, 20:15:07] INFO:	CSV-Export to: ./data2/property_immowelt_bl-hamburg.csv
# [2022-12-24, 20:15:07] SLEEP:	State delay of 5s
# [2022-12-24, 20:15:12] INFO:	Current-Loop: 13 of 32
# [2022-12-24, 20:15:14] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 1 of 35
# [2022-12-24, 20:16:44] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 2 of 35
# [2022-12-24, 20:18:13] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 3 of 35
# [2022-12-24, 20:19:43] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 4 of 35
# [2022-12-24, 20:21:12] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 5 of 35
# [2022-12-24, 20:22:42] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 6 of 35
# [2022-12-24, 20:24:12] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 7 of 35
# [2022-12-24, 20:25:43] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 8 of 35
# [2022-12-24, 20:27:14] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 9 of 35
# [2022-12-24, 20:28:45] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 10 of 35
# [2022-12-24, 20:30:16] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 11 of 35
# [2022-12-24, 20:31:46] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 12 of 35
# [2022-12-24, 20:33:17] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 13 of 35
# [2022-12-24, 20:34:47] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 14 of 35
# [2022-12-24, 20:36:18] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 15 of 35
# [2022-12-24, 20:37:48] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 16 of 35
# [2022-12-24, 20:39:18] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 17 of 35
# [2022-12-24, 20:40:48] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 18 of 35
# [2022-12-24, 20:42:18] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 19 of 35
# [2022-12-24, 20:43:49] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 20 of 35
# [2022-12-24, 20:45:19] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 21 of 35
# [2022-12-24, 20:46:49] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 22 of 35
# [2022-12-24, 20:48:20] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 23 of 35
# [2022-12-24, 20:49:50] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 24 of 35
# [2022-12-24, 20:51:22] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 25 of 35
# [2022-12-24, 20:52:53] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 26 of 35
# [2022-12-24, 20:54:26] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 27 of 35
# [2022-12-24, 20:55:56] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 28 of 35
# [2022-12-24, 20:57:27] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 29 of 35
# [2022-12-24, 20:59:00] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 30 of 35
# [2022-12-24, 21:00:34] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 31 of 35
# [2022-12-24, 21:02:06] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 32 of 35
# [2022-12-24, 21:03:37] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 33 of 35
# [2022-12-24, 21:05:09] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 34 of 35
# [2022-12-24, 21:06:43] INFO:	State: bl-hessen, Category: wohnungen, Type: kaufen, Page: 35 of 35
# [2022-12-24, 21:08:14] SLEEP:	Category delay of 5s
# [2022-12-24, 21:08:19] INFO:	Current-Loop: 14 of 32
# [2022-12-24, 21:08:21] INFO:	State: bl-hessen, Category: haeuser, Type: kaufen, Page: 1 of 35
# [2022-12-24, 21:09:56] INFO:	State: bl-hessen, Category: haeuser, Type: kaufen, Page: 2 of 35
# [2022-12-24, 21:11:28] INFO:	State: bl-hessen, Category: haeuser, Type: kaufen, Page: 3 of 35
# [2022-12-24, 21:13:01] INFO:	State: bl-hessen, Category: haeuser, Type: kaufen, Page: 4 of 35
# [2022-12-24, 21:14:35] INFO:	State: bl-hessen, Category: haeuser, Type: kaufen, Page: 5 of 35
# [2022-12-24, 21:16:07] INFO:	State: bl-hessen, Category: haeuser, Type: kaufen, Page: 6 of 35
# [2022-12-24, 21:17:41] INFO:	State: bl-hessen, Category: haeuser, Type: kaufen, Page: 7 of 35
# [2022-12-24, 21:19:15] INFO:	State: bl-hessen, Category: haeuser, Type: kaufen, Page: 8 of 35
# [2022-12-24, 21:20:47] INFO:	State: bl-hessen, Category: haeuser, Type: kaufen, Page: 9 of 35
# [2022-12-24, 21:22:20] INFO:	State: bl-hessen, Category: haeuser, Type: kaufen, Page: 10 of 35
# [2022-12-24, 21:23:55] INFO:	State: bl-hessen, Category: haeuser, Type: kaufen, Page: 11 of 35
# [2022-12-24, 21:25:28] INFO:	State: bl-hessen, Category: haeuser, Type: kaufen, Page: 12 of 35
# [2022-12-24, 21:27:04] INFO:	State: bl-hessen, Category: haeuser, Type: kaufen, Page: 13 of 35
# [2022-12-24, 21:28:39] INFO:	State: bl-hessen, Category: haeuser, Type: kaufen, Page: 14 of 35
# [2022-12-24, 21:30:13] INFO:	State: bl-hessen, Category: haeuser, Type: kaufen, Page: 15 of 35
# [2022-12-24, 21:31:48] INFO:	State: bl-hessen, Category: haeuser, Type: kaufen, Page: 16 of 35
# [2022-12-24, 21:33:24] INFO:	State: bl-hessen, Category: haeuser, Type: kaufen, Page: 17 of 35
# [2022-12-24, 21:34:59] INFO:	State: bl-hessen, Category: haeuser, Type: kaufen, Page: 18 of 35
# ...
# [2022-12-25, 11:24:19] INFO:	State: bl-sachsen-anhalt, Category: haeuser, Type: kaufen, Page: 30 of 35
# [2022-12-25, 11:26:16] INFO:	State: bl-sachsen-anhalt, Category: haeuser, Type: kaufen, Page: 31 of 35
# [2022-12-25, 11:28:14] INFO:	State: bl-sachsen-anhalt, Category: haeuser, Type: kaufen, Page: 32 of 35
# [2022-12-25, 11:30:12] INFO:	State: bl-sachsen-anhalt, Category: haeuser, Type: kaufen, Page: 33 of 35
# [2022-12-25, 11:32:09] INFO:	State: bl-sachsen-anhalt, Category: haeuser, Type: kaufen, Page: 34 of 35
# [2022-12-25, 11:34:06] INFO:	State: bl-sachsen-anhalt, Category: haeuser, Type: kaufen, Page: 35 of 35
# [2022-12-25, 11:36:03] SLEEP:	Category delay of 5s
# [2022-12-25, 11:36:08] INFO:	CSV-Export to: ./data2/property_immowelt_bl-sachsen-anhalt.csv
# [2022-12-25, 11:36:08] SLEEP:	State delay of 5s
# [2022-12-25, 11:36:13] INFO:	Current-Loop: 29 of 32
# [2022-12-25, 11:36:17] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 1 of 35
# [2022-12-25, 11:38:18] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 2 of 35
# [2022-12-25, 11:40:19] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 3 of 35
# [2022-12-25, 11:42:19] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 4 of 35
# [2022-12-25, 11:44:19] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 5 of 35
# [2022-12-25, 11:46:19] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 6 of 35
# [2022-12-25, 11:48:20] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 7 of 35
# [2022-12-25, 11:50:20] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 8 of 35
# [2022-12-25, 11:52:21] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 9 of 35
# [2022-12-25, 11:54:20] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 10 of 35
# [2022-12-25, 11:56:21] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 11 of 35
# [2022-12-25, 11:58:22] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 12 of 35
# [2022-12-25, 12:00:23] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 13 of 35
# [2022-12-25, 12:02:24] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 14 of 35
# [2022-12-25, 12:04:26] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 15 of 35
# [2022-12-25, 12:06:27] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 16 of 35
# [2022-12-25, 12:08:27] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 17 of 35
# [2022-12-25, 12:10:27] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 18 of 35
# [2022-12-25, 12:12:27] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 19 of 35
# [2022-12-25, 12:14:28] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 20 of 35
# [2022-12-25, 12:16:28] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 21 of 35
# [2022-12-25, 12:18:28] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 22 of 35
# [2022-12-25, 12:20:29] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 23 of 35
# [2022-12-25, 12:22:29] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 24 of 35
# [2022-12-25, 12:24:30] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 25 of 35
# [2022-12-25, 12:26:31] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 26 of 35
# [2022-12-25, 12:28:31] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 27 of 35
# [2022-12-25, 12:30:31] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 28 of 35
# [2022-12-25, 12:32:33] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 29 of 35
# [2022-12-25, 12:34:35] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 30 of 35
# [2022-12-25, 12:36:36] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 31 of 35
# [2022-12-25, 12:38:37] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 32 of 35
# [2022-12-25, 12:40:37] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 33 of 35
# [2022-12-25, 12:42:38] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 34 of 35
# [2022-12-25, 12:44:38] INFO:	State: bl-schleswig-holstein, Category: wohnungen, Type: kaufen, Page: 35 of 35
# [2022-12-25, 12:46:39] SLEEP:	Category delay of 5s
# [2022-12-25, 12:46:44] INFO:	Current-Loop: 30 of 32
# [2022-12-25, 12:46:48] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 1 of 35
# [2022-12-25, 12:48:49] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 2 of 35
# [2022-12-25, 12:50:50] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 3 of 35
# [2022-12-25, 12:52:50] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 4 of 35
# [2022-12-25, 12:54:53] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 5 of 35
# [2022-12-25, 12:56:56] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 6 of 35
# [2022-12-25, 12:58:57] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 7 of 35
# [2022-12-25, 13:00:59] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 8 of 35
# [2022-12-25, 13:02:59] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 9 of 35
# [2022-12-25, 13:05:01] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 10 of 35
# [2022-12-25, 13:07:03] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 11 of 35
# [2022-12-25, 13:09:04] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 12 of 35
# [2022-12-25, 13:11:06] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 13 of 35
# [2022-12-25, 13:13:09] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 14 of 35
# [2022-12-25, 13:15:10] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 15 of 35
# [2022-12-25, 13:17:12] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 16 of 35
# [2022-12-25, 13:19:14] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 17 of 35
# [2022-12-25, 13:21:16] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 18 of 35
# [2022-12-25, 13:23:19] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 19 of 35
# [2022-12-25, 13:25:21] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 20 of 35
# [2022-12-25, 13:27:24] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 21 of 35
# [2022-12-25, 13:29:26] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 22 of 35
# [2022-12-25, 13:31:28] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 23 of 35
# [2022-12-25, 13:33:30] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 24 of 35
# [2022-12-25, 13:35:32] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 25 of 35
# [2022-12-25, 13:37:34] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 26 of 35
# [2022-12-25, 13:39:38] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 27 of 35
# [2022-12-25, 13:41:43] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 28 of 35
# [2022-12-25, 13:43:46] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 29 of 35
# [2022-12-25, 13:45:51] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 30 of 35
# [2022-12-25, 13:47:56] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 31 of 35
# [2022-12-25, 13:50:03] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 32 of 35
# [2022-12-25, 13:52:08] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 33 of 35
# [2022-12-25, 13:54:15] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 34 of 35
# [2022-12-25, 13:56:21] INFO:	State: bl-schleswig-holstein, Category: haeuser, Type: kaufen, Page: 35 of 35
# [2022-12-25, 13:58:28] SLEEP:	Category delay of 5s
# [2022-12-25, 13:58:33] INFO:	CSV-Export to: ./data2/property_immowelt_bl-schleswig-holstein.csv
# [2022-12-25, 13:58:33] SLEEP:	State delay of 5s
# [2022-12-25, 13:58:38] INFO:	Current-Loop: 31 of 32
# [2022-12-25, 13:58:41] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 1 of 33
# [2022-12-25, 14:00:46] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 2 of 33
# [2022-12-25, 14:02:52] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 3 of 33
# [2022-12-25, 14:04:59] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 4 of 33
# [2022-12-25, 14:07:05] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 5 of 33
# [2022-12-25, 14:09:12] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 6 of 33
# [2022-12-25, 14:11:17] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 7 of 33
# [2022-12-25, 14:13:24] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 8 of 33
# [2022-12-25, 14:15:30] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 9 of 33
# [2022-12-25, 14:17:36] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 10 of 33
# [2022-12-25, 14:19:42] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 11 of 33
# [2022-12-25, 14:21:49] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 12 of 33
# [2022-12-25, 14:23:56] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 13 of 33
# [2022-12-25, 14:26:03] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 14 of 33
# [2022-12-25, 14:28:09] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 15 of 33
# [2022-12-25, 14:30:15] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 16 of 33
# [2022-12-25, 14:32:21] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 17 of 33
# [2022-12-25, 14:34:28] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 18 of 33
# [2022-12-25, 14:36:34] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 19 of 33
# [2022-12-25, 14:38:41] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 20 of 33
# [2022-12-25, 14:40:47] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 21 of 33
# [2022-12-25, 14:42:53] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 22 of 33
# [2022-12-25, 14:45:00] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 23 of 33
# [2022-12-25, 14:47:07] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 24 of 33
# [2022-12-25, 14:49:13] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 25 of 33
# [2022-12-25, 14:51:20] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 26 of 33
# [2022-12-25, 14:53:27] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 27 of 33
# [2022-12-25, 14:55:34] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 28 of 33
# [2022-12-25, 14:57:41] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 29 of 33
# [2022-12-25, 14:59:48] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 30 of 33
# [2022-12-25, 15:01:55] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 31 of 33
# [2022-12-25, 15:04:03] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 32 of 33
# [2022-12-25, 15:06:09] INFO:	State: bl-thueringen, Category: wohnungen, Type: kaufen, Page: 33 of 33
# [2022-12-25, 15:08:16] SLEEP:	Category delay of 5s
# [2022-12-25, 15:08:21] INFO:	Current-Loop: 32 of 32
# [2022-12-25, 15:08:24] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 1 of 35
# [2022-12-25, 15:10:28] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 2 of 35
# [2022-12-25, 15:12:31] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 3 of 35
# [2022-12-25, 15:14:35] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 4 of 35
# [2022-12-25, 15:16:40] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 5 of 35
# [2022-12-25, 15:18:44] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 6 of 35
# [2022-12-25, 15:20:49] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 7 of 35
# [2022-12-25, 15:22:53] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 8 of 35
# [2022-12-25, 15:24:56] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 9 of 35
# [2022-12-25, 15:27:00] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 10 of 35
# [2022-12-25, 15:29:05] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 11 of 35
# [2022-12-25, 15:31:10] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 12 of 35
# [2022-12-25, 15:33:14] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 13 of 35
# [2022-12-25, 15:35:18] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 14 of 35
# [2022-12-25, 15:37:23] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 15 of 35
# [2022-12-25, 15:39:27] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 16 of 35
# [2022-12-25, 15:41:31] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 17 of 35
# [2022-12-25, 15:43:34] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 18 of 35
# [2022-12-25, 15:45:38] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 19 of 35
# [2022-12-25, 15:47:43] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 20 of 35
# [2022-12-25, 15:49:47] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 21 of 35
# [2022-12-25, 15:51:50] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 22 of 35
# [2022-12-25, 15:53:55] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 23 of 35
# [2022-12-25, 15:56:00] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 24 of 35
# [2022-12-25, 15:58:05] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 25 of 35
# [2022-12-25, 16:00:09] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 26 of 35
# [2022-12-25, 16:02:14] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 27 of 35
# [2022-12-25, 16:04:18] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 28 of 35
# [2022-12-25, 16:06:23] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 29 of 35
# [2022-12-25, 16:08:27] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 30 of 35
# [2022-12-25, 16:10:31] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 31 of 35
# [2022-12-25, 16:12:35] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 32 of 35
# [2022-12-25, 16:14:40] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 33 of 35
# [2022-12-25, 16:16:44] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 34 of 35
# [2022-12-25, 16:18:49] INFO:	State: bl-thueringen, Category: haeuser, Type: kaufen, Page: 35 of 35
# [2022-12-25, 16:20:54] SLEEP:	Category delay of 5s
# [2022-12-25, 16:20:59] INFO:	CSV-Export to: ./data2/property_immowelt_bl-thueringen.csv
# [2022-12-25, 16:20:59] SLEEP:	State delay of 5s
# [2022-12-25, 16:21:05] INFO:	CSV-Export to: ./data2/property_immowelt_data.csv
# [2022-12-25, 16:21:05] SUCCESS:	Script successful finished!
