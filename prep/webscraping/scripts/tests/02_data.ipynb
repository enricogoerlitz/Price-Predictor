# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import missingno as msno

from pandas import Series, DataFrame


np.set_printoptions(suppress=True)

sns.set(rc={"figure.figsize": (12, 7), "axes.titlesize": 20, "axes.titleweight": "bold", "axes.labelsize": 15})
sns.set_palette("Set2")
warnings.filterwarnings('ignore')

# %%
def _print(data):
    pd.set_option('display.max_rows', None)
    print(data)

# %%
df = pd.read_csv("./data/property_immowelt_data.csv", sep="|")
df
# Out:
#                                         url   category buy_rent      state  \
# 0    https://www.immowelt.de/expose/27z6r5f  wohnungen   kaufen  bl-berlin
# 1    https://www.immowelt.de/expose/27pen5e  wohnungen   kaufen  bl-berlin
# 2    https://www.immowelt.de/expose/277eq5d  wohnungen   kaufen  bl-berlin
# 3    https://www.immowelt.de/expose/27mj85d  wohnungen   kaufen  bl-berlin
# 4    https://www.immowelt.de/expose/27xe55d  wohnungen   kaufen  bl-berlin
# ..                                      ...        ...      ...        ...
# 235  https://www.immowelt.de/expose/262295f    haeuser   kaufen  bl-bremen
# 236  https://www.immowelt.de/expose/27b5y5b    haeuser   kaufen  bl-bremen
# 237  https://www.immowelt.de/expose/253ja5c    haeuser   kaufen  bl-bremen
# 238  https://www.immowelt.de/expose/2456q5e    haeuser   kaufen  bl-bremen
# 239  https://www.immowelt.de/expose/27n6h5g    haeuser   kaufen  bl-bremen
#
#                                                  title      price  \
# ...

# %%
_print(df["equipments"].unique())
# Out:
# ['Wohnungslage5. Geschoss (Dachgeschoss)Bezugsofort'
#  'KategorieTerrassenwohnung' 'Bezugsofort'
#  'WohnungslageErdgeschossDerzeitige Nutzungvermietet'
#  'Wohnungslage1. GeschossBezugsofortDerzeitige Nutzungfrei'
#  'WohnungslageErdgeschoss' 'Na' 'Wohnungslage2. GeschossBezugQ3 2024'
#  'Wohnungslage1. GeschossBezugggf. nach AbspracheDerzeitige Nutzungvermietet'
#  'WohnungslageErdgeschossBezugnach Absprache'
#  'Wohnungslage1. GeschossBezugvermietet seit 01.12.2007Derzeitige Nutzungvermietet'
#  'Wohnungslage1. GeschossBezugbezugsfrei nach Absprache'
#  'WohnungslageErdgeschossBezugvermietet seit 01.06.2020'
#  'WohnungslageErdgeschossBezugvermietet seit 01.01.1978Derzeitige Nutzungvermietet'
#  'Derzeitige Nutzungfrei'
#  'Wohnungslage1. GeschossDerzeitige Nutzungvermietet'
#  'Wohnungslage3. GeschossDerzeitige Nutzungvermietet'
#  'Wohnungslage2. GeschossDerzeitige Nutzungvermietet'
#  'Wohnungslage5. GeschossDerzeitige Nutzungvermietet'
# ...

# %%
_print(df["features"].unique())
# Out:
# [' Geschäftszeiten Montag - Samstag von 09:00 Uhr - 21:00 Uhr'
#  'Nutzfläche: 167,00 m², Grundstücksfläche: 2.700,00 m², Anzahl der Schlafzimmer: 4, Anzahl Balkone: 1, Balkon-Terrassen-Fläche: 5,00 m², Bundesland: Berlin, 3 Etagen, modernisiert: 2005, Distanz zum Flughafen: 35, Distanz zum Hauptbahnhof: 50, Distanz zur Autobahn: 35, Distanz zum Bus: 2 Weniger anzeigen '
#  ' Geschäftszeiten Mo.-Fr. von 09:00 bis 17:00 Uhr'
#  'Anzahl der Schlafzimmer: 1, Anzahl der Badezimmer: 1, Bundesland: Berlin, 5 Etagen, modernisiert: 2018 Weniger anzeigen '
#  ' Geschäftszeiten Mo - Do 09.00 bis 18.00 UhrFr          09.00 bis 16.00 Uhr'
#  ' Geschäftszeiten 08:00 - 20:00 Uhr'
#  'Tiefgarage vorhanden, Ost-Balkon/Terrasse, Fahrradraum, Anzahl der Schlafzimmer: 2, Anzahl der Badezimmer: 1, Anzahl Balkone: 1, Balkon-Terrassen-Fläche: 1,98 m², Bundesland: Berlin, 4 Etagen, Lage im Bau:  hinten, Wohnungsnr.: 5.2.2.1'
# ...

# %%
_print(df["energy_data"].unique())
# Out:
# ['Energieträger: Gas;Heizungsart: Zentralheizung;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Baujahr laut Energieausweis: 1998;Wesentliche Energieträger: Gas;Gültigkeit:  22.01.2019 bis 22.01.2029 ;Effizienzklasse: D;Endenergieverbrauch:  106,74 kWh/(m²·a)  ;'
#  'Energieträger: Gas;'
#  'Energieträger: Erdwärme, Gas;Heizungsart: Zentralheizung;'
#  'Heizungsart: Zentralheizung;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Wesentliche Energieträger: Erdgas leicht;Gültigkeit:  06.02.2018 bis 06.02.2028 ;Endenergieverbrauch:  143,20 kWh/(m²·a)  ;'
#  'Energieträger: Öl;Heizungsart: Zentralheizung;Energieausweistyp: Verbrauchsausweis;Gebäudetyp: Wohngebäude;Wesentliche Energieträger: Öl;Gültigkeit:  23.08.2018 bis 23.08.2028 ;Effizienzklasse: H;Endenergieverbrauch:  259,00 kWh/(m²·a)  - Warmwasser enthalten ;'
#  nan
# ...

# %%
_print(df["keywords"].unique())
# Out:
# [' Geschäftszeiten Montag - Samstag von 09:00 Uhr - 21:00 Uhr'
#  'Nutzfläche: 167,00 m², Grundstücksfläche: 2.700,00 m², Anzahl der Schlafzimmer: 4, Anzahl Balkone: 1, Balkon-Terrassen-Fläche: 5,00 m², Bundesland: Berlin, 3 Etagen, modernisiert: 2005, Distanz zum Flughafen: 35, Distanz zum Hauptbahnhof: 50, Distanz zur Autobahn: 35, Distanz zum Bus: 2 Weniger anzeigen '
#  ' Geschäftszeiten Mo.-Fr. von 09:00 bis 17:00 Uhr'
#  'Anzahl der Schlafzimmer: 1, Anzahl der Badezimmer: 1, Bundesland: Berlin, 5 Etagen, modernisiert: 2018 Weniger anzeigen '
#  ' Geschäftszeiten Mo - Do 09.00 bis 18.00 UhrFr          09.00 bis 16.00 Uhr'
#  ' Geschäftszeiten 08:00 - 20:00 Uhr'
#  'Tiefgarage vorhanden, Ost-Balkon/Terrasse, Fahrradraum, Anzahl der Schlafzimmer: 2, Anzahl der Badezimmer: 1, Anzahl Balkone: 1, Balkon-Terrassen-Fläche: 1,98 m², Bundesland: Berlin, 4 Etagen, Lage im Bau:  hinten, Wohnungsnr.: 5.2.2.1'
# ...
